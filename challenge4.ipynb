# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler, Imputer, OneHotEncoder, LabelEncoder
from sklearn.cross_validation import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.utils import resample
import numpy as np
import seaborn as sns
import operator
import math
import tensorflow as tf

# %matplotlib inline
# Out:
# /home/maxime/local/anaconda3/lib/python3.4/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# Import
test = pd.read_csv('data/test.csv', sep=';', na_values='(MISSING)')
test['VARIABLE_CIBLE'] = 'UNKNOWN'
test['index_origin'] = test.index.tolist()

train = pd.read_csv('data/train.csv', sep=';', na_values='(MISSING)')
train['index_origin'] = -1

piv_train = train.shape[0]

# Creating a DataFrame with train+test data
df_all = pd.concat((train, test), axis=0, ignore_index=True)

# %%
df_all0 = df_all[df_all.SOURCE_CITED_AGE == 'IMPUT']
df_all1 = df_all[df_all.SOURCE_CITED_AGE == 'CALC']

# %%
class Preprocessings():
    
    
    def __init__(self, date_columns=None, cols_toDrop=None):
        self.dateCols = date_columns
        self.colsToDrop = cols_toDrop
        
        self.numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    
        
        
    def datetime_processings(self, df, format=None):
        # converting string dates in dateTime format :
        df[self.dateCols] = df[self.dateCols].apply(lambda col : pd.to_datetime(col, format=format))

        # PRIORITY_MONTH = BEGIN_MONTH :
        df = df.drop(['PRIORITY_MONTH'], axis=1)

        # creating features of duration between dates :
        df['filing-begin'] = (df.FILING_MONTH - df.BEGIN_MONTH).dt.days
        df['pub-filing'] = (df.PUBLICATION_MONTH - df.FILING_MONTH).dt.days
        df['pub_year'] = df.PUBLICATION_MONTH.dt.year
        df = df.drop(['FILING_MONTH', 'PUBLICATION_MONTH','BEGIN_MONTH'], axis=1)
        
        df = df.drop('cited_nmiss', axis=1)
        
        return df
    
    
    def cat_to_codes(self, df):
        """
        converting categorical data into numerical codes :
        NaN's will be replaced by -1
        And replacing -1 by the meadian value of each categorical column
        """
        
        self.non_num_cols = df.select_dtypes(exclude=self.numerics).columns.difference(self.dateCols)

        df[self.non_num_cols] = df[self.non_num_cols].apply(lambda col : col.astype('category').cat.codes)
        
        df[self.non_num_cols] = df[self.non_num_cols].replace(-1, df[self.non_num_cols].median())
                
        return df
    
    
def re_split(df, target, split_value=None):
    """
    When eval data set is imported, you need to create a column 'target' and filling it with
    a value that is not in the train data set. By doing so, after cat_to_codes the eval set is
    identified by the largest value in categorical 'target'
    """
    if split_value == None:
        unknown_target = df[target].unique().max()
    else :
        unknown_target = split_value
        
    df_train = df[df[target] != unknown_target]
    df_eval = df[df[target] == unknown_target]
    df_eval = df_eval.drop(target, axis=1)
        
    return df_train, df_eval

# %%
def value_counts(df):
    for col in df.columns:
        print(col)
        vals = df[col].value_counts(normalize=True, dropna=False).reset_index()
        print(vals)
        print()
        print(vals[vals['index'].isnull()])
        print('-------------------------------------')

# %%
class Used_features():
    
    def __init__(self, target):
        self.target = target
        
    def fit_transform(self, df):
        self.columns_Y = [col for col in df.columns if len(df[col].unique())>=2]
        self.columns_X = self.columns_Y.copy()
        self.columns_X.append(self.target) 
        return df[self.columns_Y]
    
    def transform(self, df):
        return df[self.columns_X]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
date_columns = ['PRIORITY_MONTH', 'FILING_MONTH', 'PUBLICATION_MONTH', 'BEGIN_MONTH']

# %%
preproc = Preprocessings(date_columns=date_columns)

df0 = preproc.datetime_processings(df_all0, format='%m/%Y')
df0 = preproc.cat_to_codes(df0)
df0 = df0.fillna(df0.median())

preproc = Preprocessings(date_columns=date_columns)

df1 = preproc.datetime_processings(df_all1, format='%m/%Y')
df1 = preproc.cat_to_codes(df1)
df1 = df1.fillna(df1.median())
# Out:
# /home/maxime/local/anaconda3/lib/python3.4/site-packages/pandas/core/frame.py:2265: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
df0_train, df0_eval = re_split(df0, 'VARIABLE_CIBLE')
df1_train, df1_eval = re_split(df1, 'VARIABLE_CIBLE')

# %%
keep_feat = Used_features('VARIABLE_CIBLE')

print(df0_eval.shape)
df0_eval = keep_feat.fit_transform(df0_eval)
df0_train = keep_feat.transform(df0_train)
print(df0_eval.shape)


print(df1_eval.shape)
df1_eval = keep_feat.fit_transform(df1_eval)
df1_train = keep_feat.transform(df1_train)
print(df1_eval.shape)
# Out:
# (84092, 48)
# (84092, 36)
# (45623, 48)
# (45623, 45)

# %% [markdown]
# # Benchmark model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
features0 = df0_eval.columns.tolist()
features0.remove('index_origin')
features1 = df1_eval.columns.tolist()
features1.remove('index_origin')

# %%
params = {'n_estimators':np.arange(5,1500,100),'max_depth':np.arange(1,110,10)}

est = RandomForestClassifier(n_jobs=6)

clf = GridSearchCV(estimator=est, param_grid=params, verbose=3)

clf.fit(df0_train[features0], df0_train['VARIABLE_CIBLE'])
# Out:
# Fitting 3 folds for each of 165 candidates, totalling 495 fits
# [CV] n_estimators=5, max_depth=1 .....................................
# [CV] ............ n_estimators=5, max_depth=1, score=0.568947 -   0.3s
# [CV] n_estimators=5, max_depth=1 .....................................
# [CV] ............ n_estimators=5, max_depth=1, score=0.568947 -   0.3s
# [CV] n_estimators=5, max_depth=1 .....................................
# [CV] ............ n_estimators=5, max_depth=1, score=0.568949 -   0.3s
# [CV] n_estimators=105, max_depth=1 ...................................
# [CV] .......... n_estimators=105, max_depth=1, score=0.568947 -   1.2s
# [CV] n_estimators=105, max_depth=1 ...................................
# [CV] .......... n_estimators=105, max_depth=1, score=0.568947 -   1.2s
# [CV] n_estimators=105, max_depth=1 ...................................
# [CV] .......... n_estimators=105, max_depth=1, score=0.568949 -   1.1s
# [CV] n_estimators=205, max_depth=1 ...................................
# [CV] .......... n_estimators=205, max_depth=1, score=0.568947 -   2.1s
# [CV] n_estimators=205, max_depth=1 ...................................
# [CV] .......... n_estimators=205, max_depth=1, score=0.568947 -   2.1s
# [CV] n_estimators=205, max_depth=1 ...................................
# [CV] .......... n_estimators=205, max_depth=1, score=0.568949 -   2.1s
# [CV] n_estimators=305, max_depth=1 ...................................
# [CV] .......... n_estimators=305, max_depth=1, score=0.568947 -   2.8s
# [CV] n_estimators=305, max_depth=1 ...................................
# [CV] .......... n_estimators=305, max_depth=1, score=0.568947 -   2.9s
# [CV] n_estimators=305, max_depth=1 ...................................
# [CV] .......... n_estimators=305, max_depth=1, score=0.568949 -   2.9s
# [CV] n_estimators=405, max_depth=1 ...................................
# [CV] .......... n_estimators=405, max_depth=1, score=0.568947 -   3.7s
# [CV] n_estimators=405, max_depth=1 ...................................
# [CV] .......... n_estimators=405, max_depth=1, score=0.568947 -   3.7s
# [CV] n_estimators=405, max_depth=1 ...................................
# [CV] .......... n_estimators=405, max_depth=1, score=0.568949 -   3.7s
# [CV] n_estimators=505, max_depth=1 ...................................
# [CV] .......... n_estimators=505, max_depth=1, score=0.568947 -   4.6s
# [CV] n_estimators=505, max_depth=1 ...................................
# [CV] .......... n_estimators=505, max_depth=1, score=0.568947 -   4.5s
# [CV] n_estimators=505, max_depth=1 ...................................
# [CV] .......... n_estimators=505, max_depth=1, score=0.568949 -   4.4s
# [CV] n_estimators=605, max_depth=1 ...................................
# [CV] .......... n_estimators=605, max_depth=1, score=0.568947 -   5.4s
# [CV] n_estimators=605, max_depth=1 ...................................
# [CV] .......... n_estimators=605, max_depth=1, score=0.568947 -   5.3s
# [CV] n_estimators=605, max_depth=1 ...................................
# [CV] .......... n_estimators=605, max_depth=1, score=0.568949 -   5.5s
# [CV] n_estimators=705, max_depth=1 ...................................
# [CV] .......... n_estimators=705, max_depth=1, score=0.568947 -   6.3s
# [CV] n_estimators=705, max_depth=1 ...................................
# [CV] .......... n_estimators=705, max_depth=1, score=0.568947 -   6.4s
# [CV] n_estimators=705, max_depth=1 ...................................
# [CV] .......... n_estimators=705, max_depth=1, score=0.568949 -   6.1s
# [CV] n_estimators=805, max_depth=1 ...................................
# [CV] .......... n_estimators=805, max_depth=1, score=0.568947 -   7.2s
# [CV] n_estimators=805, max_depth=1 ...................................
# [CV] .......... n_estimators=805, max_depth=1, score=0.568947 -   7.1s
# [CV] n_estimators=805, max_depth=1 ...................................
# [CV] .......... n_estimators=805, max_depth=1, score=0.568949 -   7.1s
# [CV] n_estimators=905, max_depth=1 ...................................
# [CV] .......... n_estimators=905, max_depth=1, score=0.568947 -   8.1s
# [CV] n_estimators=905, max_depth=1 ...................................
# [CV] .......... n_estimators=905, max_depth=1, score=0.568947 -   8.0s
# [CV] n_estimators=905, max_depth=1 ...................................
# [CV] .......... n_estimators=905, max_depth=1, score=0.568949 -   7.9s
# [CV] n_estimators=1005, max_depth=1 ..................................
# [CV] ......... n_estimators=1005, max_depth=1, score=0.568947 -   8.6s
# [CV] n_estimators=1005, max_depth=1 ..................................
# [CV] ......... n_estimators=1005, max_depth=1, score=0.568947 -   8.7s
# [CV] n_estimators=1005, max_depth=1 ..................................
# [CV] ......... n_estimators=1005, max_depth=1, score=0.568949 -   8.7s
# [CV] n_estimators=1105, max_depth=1 ..................................
# [CV] ......... n_estimators=1105, max_depth=1, score=0.568947 -   9.4s
# [CV] n_estimators=1105, max_depth=1 ..................................
# [CV] ......... n_estimators=1105, max_depth=1, score=0.568947 -   9.8s
# [CV] n_estimators=1105, max_depth=1 ..................................
# [CV] ......... n_estimators=1105, max_depth=1, score=0.568949 -   9.7s
# [CV] n_estimators=1205, max_depth=1 ..................................
# [CV] ......... n_estimators=1205, max_depth=1, score=0.568947 -  10.4s
# [CV] n_estimators=1205, max_depth=1 ..................................
# [CV] ......... n_estimators=1205, max_depth=1, score=0.568947 -  10.6s
# [CV] n_estimators=1205, max_depth=1 ..................................
# [CV] ......... n_estimators=1205, max_depth=1, score=0.568949 -  10.6s
# [CV] n_estimators=1305, max_depth=1 ..................................
# [CV] ......... n_estimators=1305, max_depth=1, score=0.568947 -  11.3s
# [CV] n_estimators=1305, max_depth=1 ..................................
# [CV] ......... n_estimators=1305, max_depth=1, score=0.568947 -  11.3s
# [CV] n_estimators=1305, max_depth=1 ..................................
# [CV] ......... n_estimators=1305, max_depth=1, score=0.568949 -  11.5s
# [CV] n_estimators=1405, max_depth=1 ..................................
# [CV] ......... n_estimators=1405, max_depth=1, score=0.568947 -  12.1s
# [CV] n_estimators=1405, max_depth=1 ..................................
# [CV] ......... n_estimators=1405, max_depth=1, score=0.568947 -  12.3s
# [CV] n_estimators=1405, max_depth=1 ..................................
# [CV] ......... n_estimators=1405, max_depth=1, score=0.568949 -  12.0s
# [CV] n_estimators=5, max_depth=11 ....................................
# [CV] ........... n_estimators=5, max_depth=11, score=0.639164 -   0.5s
# [CV] n_estimators=5, max_depth=11 ....................................
# [CV] ........... n_estimators=5, max_depth=11, score=0.642742 -   0.5s
# [CV] n_estimators=5, max_depth=11 ....................................
# [CV] ........... n_estimators=5, max_depth=11, score=0.638722 -   0.5s
# [CV] n_estimators=105, max_depth=11 ..................................
# [CV] ......... n_estimators=105, max_depth=11, score=0.651293 -   4.8s
# [CV] n_estimators=105, max_depth=11 ..................................
# [CV] ......... n_estimators=105, max_depth=11, score=0.652689 -   4.5s
# [CV] n_estimators=105, max_depth=11 ..................................
# [CV] ......... n_estimators=105, max_depth=11, score=0.650011 -   4.8s
# [CV] n_estimators=205, max_depth=11 ..................................
# [CV] ......... n_estimators=205, max_depth=11, score=0.651526 -   8.4s
# [CV] n_estimators=205, max_depth=11 ..................................
# [CV] ......... n_estimators=205, max_depth=11, score=0.653852 -   9.0s
# [CV] n_estimators=205, max_depth=11 ..................................
# [CV] ......... n_estimators=205, max_depth=11, score=0.650923 -   8.4s
# [CV] n_estimators=305, max_depth=11 ..................................
# [CV] ......... n_estimators=305, max_depth=11, score=0.651276 -  12.6s
# [CV] n_estimators=305, max_depth=11 ..................................
# [CV] ......... n_estimators=305, max_depth=11, score=0.652635 -  12.5s
# [CV] n_estimators=305, max_depth=11 ..................................
# [CV] ......... n_estimators=305, max_depth=11, score=0.650852 -  13.3s
# [CV] n_estimators=405, max_depth=11 ..................................
# [CV] ......... n_estimators=405, max_depth=11, score=0.652259 -  17.6s
# [CV] n_estimators=405, max_depth=11 ..................................
# [CV] ......... n_estimators=405, max_depth=11, score=0.652957 -  18.0s
# [CV] n_estimators=405, max_depth=11 ..................................
# [CV] ......... n_estimators=405, max_depth=11, score=0.650583 -  17.6s
# [CV] n_estimators=505, max_depth=11 ..................................
# [CV] ......... n_estimators=505, max_depth=11, score=0.650721 -  21.9s
# [CV] n_estimators=505, max_depth=11 ..................................
# [CV] ......... n_estimators=505, max_depth=11, score=0.652975 -  22.0s
# [CV] n_estimators=505, max_depth=11 ..................................
# [CV] ......... n_estimators=505, max_depth=11, score=0.650834 -  21.8s
# [CV] n_estimators=605, max_depth=11 ..................................
# [CV] ......... n_estimators=605, max_depth=11, score=0.651401 -  26.0s
# [CV] n_estimators=605, max_depth=11 ..................................
# [CV] ......... n_estimators=605, max_depth=11, score=0.653404 -  25.1s
# [CV] n_estimators=605, max_depth=11 ..................................
# [CV] ......... n_estimators=605, max_depth=11, score=0.650637 -  26.8s
# [CV] n_estimators=705, max_depth=11 ..................................
# [CV] ......... n_estimators=705, max_depth=11, score=0.652474 -  30.6s
# [CV] n_estimators=705, max_depth=11 ..................................
# [CV] ......... n_estimators=705, max_depth=11, score=0.653512 -  29.4s
# [CV] n_estimators=705, max_depth=11 ..................................
# [CV] ......... n_estimators=705, max_depth=11, score=0.650780 -  30.1s
# [CV] n_estimators=805, max_depth=11 ..................................
# [CV] ......... n_estimators=805, max_depth=11, score=0.651598 -  35.0s
# [CV] n_estimators=805, max_depth=11 ..................................
# [CV] ......... n_estimators=805, max_depth=11, score=0.653709 -  34.0s
# [CV] n_estimators=805, max_depth=11 ..................................
# [CV] ......... n_estimators=805, max_depth=11, score=0.650887 -  33.8s
# [CV] n_estimators=905, max_depth=11 ..................................
# [CV] ......... n_estimators=905, max_depth=11, score=0.652349 -  37.5s
# [CV] n_estimators=905, max_depth=11 ..................................
# [CV] ......... n_estimators=905, max_depth=11, score=0.654084 -  37.8s
# [CV] n_estimators=905, max_depth=11 ..................................
# [CV] ......... n_estimators=905, max_depth=11, score=0.650869 -  38.4s
# [CV] n_estimators=1005, max_depth=11 .................................
# [CV] ........ n_estimators=1005, max_depth=11, score=0.652331 -  42.6s
# [CV] n_estimators=1005, max_depth=11 .................................
# [CV] ........ n_estimators=1005, max_depth=11, score=0.653834 -  41.7s
# [CV] n_estimators=1005, max_depth=11 .................................
# [CV] ........ n_estimators=1005, max_depth=11, score=0.650565 -  42.3s
# [CV] n_estimators=1105, max_depth=11 .................................
# [CV] ........ n_estimators=1105, max_depth=11, score=0.651937 -  45.4s
# [CV] n_estimators=1105, max_depth=11 .................................
# [CV] ........ n_estimators=1105, max_depth=11, score=0.654442 -  47.0s
# [CV] n_estimators=1105, max_depth=11 .................................
# [CV] ........ n_estimators=1105, max_depth=11, score=0.651227 -  46.3s
# [CV] n_estimators=1205, max_depth=11 .................................
# [CV] ........ n_estimators=1205, max_depth=11, score=0.652206 -  50.9s
# [CV] n_estimators=1205, max_depth=11 .................................
# [CV] ........ n_estimators=1205, max_depth=11, score=0.653852 -  50.2s
# [CV] n_estimators=1205, max_depth=11 .................................
# [CV] ........ n_estimators=1205, max_depth=11, score=0.650959 -  49.8s
# [CV] n_estimators=1305, max_depth=11 .................................
# [CV] ........ n_estimators=1305, max_depth=11, score=0.651884 -  57.3s
# [CV] n_estimators=1305, max_depth=11 .................................
# [CV] ........ n_estimators=1305, max_depth=11, score=0.654299 -  52.6s
# [CV] n_estimators=1305, max_depth=11 .................................
# [CV] ........ n_estimators=1305, max_depth=11, score=0.650852 -  58.0s
# [CV] n_estimators=1405, max_depth=11 .................................
# [CV] ........ n_estimators=1405, max_depth=11, score=0.652152 -  59.1s
# [CV] n_estimators=1405, max_depth=11 .................................
# [CV] ........ n_estimators=1405, max_depth=11, score=0.654245 -  59.1s
# [CV] n_estimators=1405, max_depth=11 .................................
# [CV] ........ n_estimators=1405, max_depth=11, score=0.650780 -  59.6s
# [CV] n_estimators=5, max_depth=21 ....................................
# [CV] ........... n_estimators=5, max_depth=21, score=0.622026 -   0.6s
# [CV] n_estimators=5, max_depth=21 ....................................
# [CV] ........... n_estimators=5, max_depth=21, score=0.619611 -   0.6s
# [CV] n_estimators=5, max_depth=21 ....................................
# [CV] ........... n_estimators=5, max_depth=21, score=0.618649 -   0.6s
# [CV] n_estimators=105, max_depth=21 ..................................
# [CV] ......... n_estimators=105, max_depth=21, score=0.657465 -   7.2s
# [CV] n_estimators=105, max_depth=21 ..................................
# [CV] ......... n_estimators=105, max_depth=21, score=0.658825 -   6.8s
# [CV] n_estimators=105, max_depth=21 ..................................
# [CV] ......... n_estimators=105, max_depth=21, score=0.656415 -   6.6s
# [CV] n_estimators=205, max_depth=21 ..................................
# [CV] ......... n_estimators=205, max_depth=21, score=0.659612 -  13.7s
# [CV] n_estimators=205, max_depth=21 ..................................
# [CV] ......... n_estimators=205, max_depth=21, score=0.660900 -  13.3s
# [CV] n_estimators=205, max_depth=21 ..................................
# [CV] ......... n_estimators=205, max_depth=21, score=0.657686 -  13.5s
# [CV] n_estimators=305, max_depth=21 ..................................
# [CV] ......... n_estimators=305, max_depth=21, score=0.660095 -  19.4s
# [CV] n_estimators=305, max_depth=21 ..................................
# [CV] ......... n_estimators=305, max_depth=21, score=0.661330 -  19.5s
# [CV] n_estimators=305, max_depth=21 ..................................
# [CV] ......... n_estimators=305, max_depth=21, score=0.658222 -  19.6s
# [CV] n_estimators=405, max_depth=21 ..................................
# [CV] ......... n_estimators=405, max_depth=21, score=0.661222 -  26.2s
# [CV] n_estimators=405, max_depth=21 ..................................
# [CV] ......... n_estimators=405, max_depth=21, score=0.660364 -  26.6s
# [CV] n_estimators=405, max_depth=21 ..................................
# [CV] ......... n_estimators=405, max_depth=21, score=0.659278 -  26.2s
# [CV] n_estimators=505, max_depth=21 ..................................
# [CV] ......... n_estimators=505, max_depth=21, score=0.660900 -  32.9s
# [CV] n_estimators=505, max_depth=21 ..................................
# [CV] ......... n_estimators=505, max_depth=21, score=0.660811 -  32.1s
# [CV] n_estimators=505, max_depth=21 ..................................
# [CV] ......... n_estimators=505, max_depth=21, score=0.658849 -  31.5s
# [CV] n_estimators=605, max_depth=21 ..................................
# [CV] ......... n_estimators=605, max_depth=21, score=0.660918 -  38.8s
# [CV] n_estimators=605, max_depth=21 ..................................
# [CV] ......... n_estimators=605, max_depth=21, score=0.661652 -  38.7s
# [CV] n_estimators=605, max_depth=21 ..................................
# [CV] ......... n_estimators=605, max_depth=21, score=0.658831 -  39.3s
# [CV] n_estimators=705, max_depth=21 ..................................
# [CV] ......... n_estimators=705, max_depth=21, score=0.660703 -  44.4s
# [CV] n_estimators=705, max_depth=21 ..................................
# [CV] ......... n_estimators=705, max_depth=21, score=0.661437 -  46.4s
# [CV] n_estimators=705, max_depth=21 ..................................
# [CV] ......... n_estimators=705, max_depth=21, score=0.659117 -  45.4s
# [CV] n_estimators=805, max_depth=21 ..................................
# [CV] ......... n_estimators=805, max_depth=21, score=0.660900 -  53.0s
# [CV] n_estimators=805, max_depth=21 ..................................
# [CV] ......... n_estimators=805, max_depth=21, score=0.661616 -  54.4s
# [CV] n_estimators=805, max_depth=21 ..................................
# [CV] ......... n_estimators=805, max_depth=21, score=0.658866 -  51.6s
# [CV] n_estimators=905, max_depth=21 ..................................
# [CV] ......... n_estimators=905, max_depth=21, score=0.661830 -  57.5s
# [CV] n_estimators=905, max_depth=21 ..................................
# [CV] ......... n_estimators=905, max_depth=21, score=0.661365 -  55.5s
# [CV] n_estimators=905, max_depth=21 ..................................
# [CV] ......... n_estimators=905, max_depth=21, score=0.660065 -  59.3s
# [CV] n_estimators=1005, max_depth=21 .................................
# [CV] ........ n_estimators=1005, max_depth=21, score=0.661777 - 1.1min
# [CV] n_estimators=1005, max_depth=21 .................................
# [CV] ........ n_estimators=1005, max_depth=21, score=0.661991 - 1.1min
# [CV] n_estimators=1005, max_depth=21 .................................
# [CV] ........ n_estimators=1005, max_depth=21, score=0.658670 - 1.1min
# [CV] n_estimators=1105, max_depth=21 .................................
# [CV] ........ n_estimators=1105, max_depth=21, score=0.660847 - 1.2min
# [CV] n_estimators=1105, max_depth=21 .................................
# [CV] ........ n_estimators=1105, max_depth=21, score=0.663244 - 1.2min
# [CV] n_estimators=1105, max_depth=21 .................................
# [CV] ........ n_estimators=1105, max_depth=21, score=0.658240 - 1.2min
# [CV] n_estimators=1205, max_depth=21 .................................
# [CV] ........ n_estimators=1205, max_depth=21, score=0.660542 - 1.3min
# [Parallel(n_jobs=1)]: Done  31 tasks       | elapsed:  2.2min
# [Parallel(n_jobs=1)]: Done 127 tasks       | elapsed: 50.0min
# [CV] n_estimators=1205, max_depth=21 .................................
# [CV] ........ n_estimators=1205, max_depth=21, score=0.662439 - 1.3min
# [CV] n_estimators=1205, max_depth=21 .................................
# [CV] ........ n_estimators=1205, max_depth=21, score=0.658527 - 1.3min
# [CV] n_estimators=1305, max_depth=21 .................................
# [CV] ........ n_estimators=1305, max_depth=21, score=0.660918 - 1.4min
# [CV] n_estimators=1305, max_depth=21 .................................
# [CV] ........ n_estimators=1305, max_depth=21, score=0.662492 - 1.3min
# [CV] n_estimators=1305, max_depth=21 .................................
# [CV] ........ n_estimators=1305, max_depth=21, score=0.659367 - 1.4min
# [CV] n_estimators=1405, max_depth=21 .................................
# [CV] ........ n_estimators=1405, max_depth=21, score=0.660525 - 1.5min
# [CV] n_estimators=1405, max_depth=21 .................................
# [CV] ........ n_estimators=1405, max_depth=21, score=0.662582 - 1.5min
# [CV] n_estimators=1405, max_depth=21 .................................
# [CV] ........ n_estimators=1405, max_depth=21, score=0.658688 - 1.5min
# [CV] n_estimators=5, max_depth=31 ....................................
# [CV] ........... n_estimators=5, max_depth=31, score=0.605156 -   0.7s
# [CV] n_estimators=5, max_depth=31 ....................................
# [CV] ........... n_estimators=5, max_depth=31, score=0.611328 -   0.6s
# [CV] n_estimators=5, max_depth=31 ....................................
# [CV] ........... n_estimators=5, max_depth=31, score=0.606322 -   0.7s
# [CV] n_estimators=105, max_depth=31 ..................................
# [CV] ......... n_estimators=105, max_depth=31, score=0.655068 -   8.1s
# [CV] n_estimators=105, max_depth=31 ..................................
# [CV] ......... n_estimators=105, max_depth=31, score=0.653655 -   7.9s
# [CV] n_estimators=105, max_depth=31 ..................................
# [CV] ......... n_estimators=105, max_depth=31, score=0.652659 -   7.7s
# [CV] n_estimators=205, max_depth=31 ..................................
# [CV] ......... n_estimators=205, max_depth=31, score=0.655587 -  15.3s
# [CV] n_estimators=205, max_depth=31 ..................................
# [CV] ......... n_estimators=205, max_depth=31, score=0.657823 -  15.3s
# [CV] n_estimators=205, max_depth=31 ..................................
# [CV] ......... n_estimators=205, max_depth=31, score=0.655109 -  15.8s
# [CV] n_estimators=305, max_depth=31 ..................................
# [CV] ......... n_estimators=305, max_depth=31, score=0.656535 -  22.8s
# [CV] n_estimators=305, max_depth=31 ..................................
# [CV] ......... n_estimators=305, max_depth=31, score=0.657770 -  22.8s
# [CV] n_estimators=305, max_depth=31 ..................................
# [CV] ......... n_estimators=305, max_depth=31, score=0.656845 -  21.8s
# [CV] n_estimators=405, max_depth=31 ..................................
# [CV] ......... n_estimators=405, max_depth=31, score=0.657537 -  29.9s
# [CV] n_estimators=405, max_depth=31 ..................................
# [CV] ......... n_estimators=405, max_depth=31, score=0.659308 -  31.5s
# [CV] n_estimators=405, max_depth=31 ..................................
# [CV] ......... n_estimators=405, max_depth=31, score=0.656022 -  29.2s
# [CV] n_estimators=505, max_depth=31 ..................................
# [CV] ......... n_estimators=505, max_depth=31, score=0.657698 -  37.7s
# [CV] n_estimators=505, max_depth=31 ..................................
# [CV] ......... n_estimators=505, max_depth=31, score=0.657680 -  36.3s
# [CV] n_estimators=505, max_depth=31 ..................................
# [CV] ......... n_estimators=505, max_depth=31, score=0.656559 -  36.8s
# [CV] n_estimators=605, max_depth=31 ..................................
# [CV] ......... n_estimators=605, max_depth=31, score=0.656964 -  44.3s
# [CV] n_estimators=605, max_depth=31 ..................................
# [CV] ......... n_estimators=605, max_depth=31, score=0.658467 -  43.8s
# [CV] n_estimators=605, max_depth=31 ..................................
# [CV] ......... n_estimators=605, max_depth=31, score=0.655932 -  45.1s
# [CV] n_estimators=705, max_depth=31 ..................................
# [CV] ......... n_estimators=705, max_depth=31, score=0.656678 -  52.4s
# [CV] n_estimators=705, max_depth=31 ..................................
# [CV] ......... n_estimators=705, max_depth=31, score=0.658932 -  50.6s
# [CV] n_estimators=705, max_depth=31 ..................................
# [CV] ......... n_estimators=705, max_depth=31, score=0.656755 -  53.3s
# [CV] n_estimators=805, max_depth=31 ..................................
# [CV] ......... n_estimators=805, max_depth=31, score=0.657984 -  57.5s
# [CV] n_estimators=805, max_depth=31 ..................................
# [CV] ......... n_estimators=805, max_depth=31, score=0.658628 -  59.0s
# [CV] n_estimators=805, max_depth=31 ..................................
# [CV] ......... n_estimators=805, max_depth=31, score=0.657024 -  57.2s
# [CV] n_estimators=905, max_depth=31 ..................................
# [CV] ......... n_estimators=905, max_depth=31, score=0.658682 - 1.1min
# [CV] n_estimators=905, max_depth=31 ..................................
# [CV] ......... n_estimators=905, max_depth=31, score=0.659755 - 1.1min
# [CV] n_estimators=905, max_depth=31 ..................................
# [CV] ......... n_estimators=905, max_depth=31, score=0.657060 - 1.1min
# [CV] n_estimators=1005, max_depth=31 .................................
# [CV] ........ n_estimators=1005, max_depth=31, score=0.657966 - 1.2min
# [CV] n_estimators=1005, max_depth=31 .................................
# [CV] ........ n_estimators=1005, max_depth=31, score=0.659183 - 1.2min
# [CV] n_estimators=1005, max_depth=31 .................................
# [CV] ........ n_estimators=1005, max_depth=31, score=0.657060 - 1.2min
# [CV] n_estimators=1105, max_depth=31 .................................
# [CV] ........ n_estimators=1105, max_depth=31, score=0.657179 - 1.3min
# [CV] n_estimators=1105, max_depth=31 .................................
# [CV] ........ n_estimators=1105, max_depth=31, score=0.658217 - 1.3min
# [CV] n_estimators=1105, max_depth=31 .................................
# [CV] ........ n_estimators=1105, max_depth=31, score=0.657507 - 1.3min
# [CV] n_estimators=1205, max_depth=31 .................................
# [CV] ........ n_estimators=1205, max_depth=31, score=0.658199 - 1.5min
# [CV] n_estimators=1205, max_depth=31 .................................
# [CV] ........ n_estimators=1205, max_depth=31, score=0.659147 - 1.5min
# [CV] n_estimators=1205, max_depth=31 .................................
# [CV] ........ n_estimators=1205, max_depth=31, score=0.656487 - 1.5min
# [CV] n_estimators=1305, max_depth=31 .................................
# [CV] ........ n_estimators=1305, max_depth=31, score=0.658270 - 1.5min
# [CV] n_estimators=1305, max_depth=31 .................................
# [CV] ........ n_estimators=1305, max_depth=31, score=0.659451 - 1.6min
# [CV] n_estimators=1305, max_depth=31 .................................
# [CV] ........ n_estimators=1305, max_depth=31, score=0.656594 - 1.6min
# [CV] n_estimators=1405, max_depth=31 .................................
# [CV] ........ n_estimators=1405, max_depth=31, score=0.657984 - 1.7min
# [CV] n_estimators=1405, max_depth=31 .................................
# [CV] ........ n_estimators=1405, max_depth=31, score=0.659254 - 1.7min
# [CV] n_estimators=1405, max_depth=31 .................................
# [CV] ........ n_estimators=1405, max_depth=31, score=0.657543 - 1.7min
# [CV] n_estimators=5, max_depth=41 ....................................
# [CV] ........... n_estimators=5, max_depth=41, score=0.607213 -   0.6s
# [CV] n_estimators=5, max_depth=41 ....................................
# [CV] ........... n_estimators=5, max_depth=41, score=0.606641 -   0.7s
# [CV] n_estimators=5, max_depth=41 ....................................
# [CV] ........... n_estimators=5, max_depth=41, score=0.606215 -   0.6s
# [CV] n_estimators=105, max_depth=41 ..................................
# [CV] ......... n_estimators=105, max_depth=41, score=0.652027 -   7.6s
# [CV] n_estimators=105, max_depth=41 ..................................
# [CV] ......... n_estimators=105, max_depth=41, score=0.654710 -   7.5s
# [CV] n_estimators=105, max_depth=41 ..................................
# [CV] ......... n_estimators=105, max_depth=41, score=0.651621 -   7.4s
# [CV] n_estimators=205, max_depth=41 ..................................
# [CV] ......... n_estimators=205, max_depth=41, score=0.654353 -  14.8s
# [CV] n_estimators=205, max_depth=41 ..................................
# [CV] ......... n_estimators=205, max_depth=41, score=0.655372 -  15.0s
# [CV] n_estimators=205, max_depth=41 ..................................
# [CV] ......... n_estimators=205, max_depth=41, score=0.653589 -  14.7s
# [CV] n_estimators=305, max_depth=41 ..................................
# [CV] ......... n_estimators=305, max_depth=41, score=0.656088 -  24.1s
# [CV] n_estimators=305, max_depth=41 ..................................
# [CV] ......... n_estimators=305, max_depth=41, score=0.657251 -  22.9s
# [CV] n_estimators=305, max_depth=41 ..................................
# [CV] ......... n_estimators=305, max_depth=41, score=0.654805 -  22.4s
# [CV] n_estimators=405, max_depth=41 ..................................
# [CV] ......... n_estimators=405, max_depth=41, score=0.655390 -  30.1s
# [CV] n_estimators=405, max_depth=41 ..................................
# [CV] ......... n_estimators=405, max_depth=41, score=0.656338 -  30.7s
# [CV] n_estimators=405, max_depth=41 ..................................
# [CV] ......... n_estimators=405, max_depth=41, score=0.654787 -  29.0s
# [CV] n_estimators=505, max_depth=41 ..................................
# [CV] ......... n_estimators=505, max_depth=41, score=0.656678 -  36.5s
# [CV] n_estimators=505, max_depth=41 ..................................
# [CV] ......... n_estimators=505, max_depth=41, score=0.657805 -  35.5s
# [CV] n_estimators=505, max_depth=41 ..................................
# [CV] ......... n_estimators=505, max_depth=41, score=0.654984 -  36.1s
# [CV] n_estimators=605, max_depth=41 ..................................
# [CV] ......... n_estimators=605, max_depth=41, score=0.655909 -  45.1s
# [CV] n_estimators=605, max_depth=41 ..................................
# [CV] ......... n_estimators=605, max_depth=41, score=0.657501 -  41.9s
# [CV] n_estimators=605, max_depth=41 ..................................
# [CV] ......... n_estimators=605, max_depth=41, score=0.655324 -  42.9s
# [CV] n_estimators=705, max_depth=41 ..................................
# [CV] ......... n_estimators=705, max_depth=41, score=0.656607 -  51.4s
# [CV] n_estimators=705, max_depth=41 ..................................
# [CV] ......... n_estimators=705, max_depth=41, score=0.657304 -  49.6s
# [CV] n_estimators=705, max_depth=41 ..................................
# [CV] ......... n_estimators=705, max_depth=41, score=0.655324 -  51.5s
# [CV] n_estimators=805, max_depth=41 ..................................
# [CV] ......... n_estimators=805, max_depth=41, score=0.656678 -  57.7s
# [CV] n_estimators=805, max_depth=41 ..................................
# [CV] ......... n_estimators=805, max_depth=41, score=0.658181 -  57.1s
# [CV] n_estimators=805, max_depth=41 ..................................
# [CV] ......... n_estimators=805, max_depth=41, score=0.654215 -  57.5s
# [CV] n_estimators=905, max_depth=41 ..................................
# [CV] ......... n_estimators=905, max_depth=41, score=0.656964 - 1.1min
# [CV] n_estimators=905, max_depth=41 ..................................
# [CV] ......... n_estimators=905, max_depth=41, score=0.658145 - 1.1min
# [CV] n_estimators=905, max_depth=41 ..................................
# [CV] ......... n_estimators=905, max_depth=41, score=0.654752 - 1.2min
# [CV] n_estimators=1005, max_depth=41 .................................
# [CV] ........ n_estimators=1005, max_depth=41, score=0.656553 - 1.2min
# [CV] n_estimators=1005, max_depth=41 .................................
# [CV] ........ n_estimators=1005, max_depth=41, score=0.658360 - 1.2min
# [CV] n_estimators=1005, max_depth=41 .................................
# [CV] ........ n_estimators=1005, max_depth=41, score=0.655915 - 1.2min
# [CV] n_estimators=1105, max_depth=41 .................................
# [CV] ........ n_estimators=1105, max_depth=41, score=0.656392 - 1.3min
# [CV] n_estimators=1105, max_depth=41 .................................
# [CV] ........ n_estimators=1105, max_depth=41, score=0.658897 - 1.4min
# [CV] n_estimators=1105, max_depth=41 .................................
# [CV] ........ n_estimators=1105, max_depth=41, score=0.656863 - 1.3min
# [CV] n_estimators=1205, max_depth=41 .................................
