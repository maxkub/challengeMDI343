# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler, Imputer, OneHotEncoder, LabelEncoder
from sklearn.cross_validation import train_test_split
import numpy as np
import seaborn as sns
import operator
import math
from data_science import *
import xgboost as xgb
from hyperopt import fmin, tpe, hp, fmin, STATUS_OK, Trials
from hyperopt.mongoexp import MongoTrials

# %matplotlib inline

# %%
# train and test data are imported in a single dataframe to do the preprocessings
# using import_data from utils/data_science.py module
df_all = import_data('data/train.csv', 'data/test.csv', 'VARIABLE_CIBLE', na_values='(MISSING)')

# creating two subsets of data
df_all0 = df_all[df_all.SOURCE_CITED_AGE == 'IMPUT']
df_all1 = df_all[df_all.SOURCE_CITED_AGE == 'CALC']

date_columns = ['PRIORITY_MONTH', 'FILING_MONTH', 'PUBLICATION_MONTH', 'BEGIN_MONTH']

# preprocessings using the Preprocessing class in the utils/data_science.py module
preproc = Preprocessings(date_columns=date_columns)

df0 = preproc.datetime_processings(df_all0, format='%m/%Y')
df0 = preproc.cat_to_codes(df0)
df0 = df0.fillna(df0.median())
df0 = df0.dropna(axis=1, how='all')


preproc = Preprocessings(date_columns=date_columns)

df1 = preproc.datetime_processings(df_all1, format='%m/%Y')
df1 = preproc.cat_to_codes(df1)
df1 = df1.fillna(df1.median())
df1 = df1.dropna(axis=1, how='all')

# splitting the train and test data (re_split is in utils.data_science.py)
df0_train, df0_eval = re_split(df0, 'VARIABLE_CIBLE')
df1_train, df1_eval = re_split(df1, 'VARIABLE_CIBLE')
# Out:
# Index([u'COUNTRY', u'FIRST_CLASSE', u'FISRT_APP_COUNTRY', u'FISRT_APP_TYPE',
#        u'FISRT_INV_COUNTRY', u'FISRT_INV_TYPE', u'LANGUAGE_OF_FILLING',
#        u'MAIN_IPC', u'SOURCE_BEGIN_MONTH', u'SOURCE_CITED_AGE',
#        u'SOURCE_IDX_ORI', u'SOURCE_IDX_RAD', u'TECHNOLOGIE_FIELD',
#        u'TECHNOLOGIE_SECTOR', u'VARIABLE_CIBLE', u'VOIE_DEPOT'],
#       dtype='object')
# Index([u'COUNTRY', u'FIRST_CLASSE', u'FISRT_APP_COUNTRY', u'FISRT_APP_TYPE',
#        u'FISRT_INV_COUNTRY', u'FISRT_INV_TYPE', u'LANGUAGE_OF_FILLING',
#        u'MAIN_IPC', u'SOURCE_BEGIN_MONTH', u'SOURCE_CITED_AGE',
#        u'SOURCE_IDX_ORI', u'SOURCE_IDX_RAD', u'TECHNOLOGIE_FIELD',
#        u'TECHNOLOGIE_SECTOR', u'VARIABLE_CIBLE', u'VOIE_DEPOT'],
#       dtype='object')
# /home/maxime/local/anaconda3/envs/env-python2.7/lib/python2.7/site-packages/pandas/core/frame.py:2320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %% [markdown]
# # hyperopt

# %%
trials = MongoTrials('mongo://localhost:1234/xgboost/jobs', exp_key='exp1')
best = fmin(math.sin, hp.uniform('x', -2, 2), trials=trials, algo=tpe.suggest, max_evals=10)

print(best)
# Out:
# WARNING:hyperopt.mongoexp:no last_id found, re-trying
# {u'x': -1.3109299800151657}

# %%
def score(params):
    """
    The score function to use in hyperopt.
    It is the validation error of xgboost models
    """
    print "Training with params : "
    print params
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    dtrain = xgb.DMatrix(X_train, label=y_train, weight=weight )
    dvalid = xgb.DMatrix(X_test, label=y_test)
    # watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
    model = xgb.train(params, dtrain, num_round)
    predictions = model.predict(dvalid)
    score = - roc_auc_score(y_test, predictions)
    print "\tScore {0}\n\n".format(score)
    return {'loss': score, 'status': STATUS_OK}


def optimize(trials):
    """
    Defining the space to explore, looking for the minimum score.
    """
    space = {
             'n_estimators' : hp.quniform('n_estimators', 100, 1000, 1),
             'eta' : hp.quniform('eta', 0.025, 0.5, 0.025),
             'max_depth' : hp.quniform('max_depth', 1, 13, 1),
             'min_child_weight' : hp.quniform('min_child_weight', 1, 6, 1),
             'subsample' : hp.quniform('subsample', 0.5, 1, 0.05),
             'gamma' : hp.quniform('gamma', 0.5, 1, 0.05),
             'colsample_bytree' : hp.quniform('colsample_bytree', 0.5, 1, 0.05),
             'eval_metric': 'auc',
             'objective': 'binary:logistic',
             'scale_pos_weight' : sum_wneg/sum_wpos,
             'nthread' : 6,
             'silent' : 0
             }

    best = fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=250)

    print best

# %% [markdown]
# ## optimization on df0

# %%
# columns selected for df0_train after RFECV
columns0 = ['APP_NB', 'APP_NB_PAYS', 'APP_NB_TYPE', 'COUNTRY', 'FIRST_CLASSE', 'FISRT_APP_COUNTRY', 
           'FISRT_APP_TYPE', 'FISRT_INV_COUNTRY', 'FISRT_INV_TYPE', 'INV_NB', 'INV_NB_PAYS', 
           'INV_NB_TYPE', 'LANGUAGE_OF_FILLING', 'MAIN_IPC', 'NB_BACKWARD', 'NB_BACKWARD_AUTRE', 
           'NB_BACKWARD_NPL', 'NB_BACKWARD_PL', 'NB_BACKWARD_XY', 'NB_CLASSES', 'NB_FIELDS', 
           'NB_ROOT_CLASSES', 'NB_SECTORS', 'TECHNOLOGIE_FIELD', 'TECHNOLOGIE_SECTOR', 'VOIE_DEPOT', 
           'oecd_NB_BACKWARD_NPL', 'oecd_NB_BACKWARD_PL', 'oecd_NB_ROOT_CLASSES', 'pct_NB_IPC', 'pct_NB_IPC_LY',
           'filing-begin', 'pub-filing', 'pub_year', 'VARIABLE_CIBLE']

removed = [col for col in df0_train.columns if col not in columns0]
print(removed)

df_train0, df_test0 = train_test_split(df0_train[columns0], test_size=0.2, random_state=42)

columns0.remove('VARIABLE_CIBLE')


test_size = len(df_test0)
train_size = len(df_train0)
# rescale weight to make it same as test set
weight = np.ones(train_size) * float(test_size) / float(train_size)

print(df_train0.columns)

# computing weights to balance the repartition of 'VARIABLE_CIBLE'values
sum_wpos = sum( weight[i] for i in range(train_size) if df_train0['VARIABLE_CIBLE'].iloc[i] == 1.0  )
sum_wneg = sum( weight[i] for i in range(train_size) if df_train0['VARIABLE_CIBLE'].iloc[i] == 0.0  )
# Out:
# ['IDX_ORIGIN', 'IDX_RADIC', 'NB_BACKWARD_I', 'SOURCE_BEGIN_MONTH', 'SOURCE_CITED_AGE', 'SOURCE_IDX_ORI', 'SOURCE_IDX_RAD', 'cited_age_max', 'cited_age_mean', 'cited_age_median', 'cited_age_min', 'index_origin']
# Index([u'APP_NB', u'APP_NB_PAYS', u'APP_NB_TYPE', u'COUNTRY', u'FIRST_CLASSE',
#        u'FISRT_APP_COUNTRY', u'FISRT_APP_TYPE', u'FISRT_INV_COUNTRY',
#        u'FISRT_INV_TYPE', u'INV_NB', u'INV_NB_PAYS', u'INV_NB_TYPE',
#        u'LANGUAGE_OF_FILLING', u'MAIN_IPC', u'NB_BACKWARD',
#        u'NB_BACKWARD_AUTRE', u'NB_BACKWARD_NPL', u'NB_BACKWARD_PL',
#        u'NB_BACKWARD_XY', u'NB_CLASSES', u'NB_FIELDS', u'NB_ROOT_CLASSES',
#        u'NB_SECTORS', u'TECHNOLOGIE_FIELD', u'TECHNOLOGIE_SECTOR',
#        u'VOIE_DEPOT', u'oecd_NB_BACKWARD_NPL', u'oecd_NB_BACKWARD_PL',
#        u'oecd_NB_ROOT_CLASSES', u'pct_NB_IPC', u'pct_NB_IPC_LY',
#        u'filing-begin', u'pub-filing', u'pub_year', u'VARIABLE_CIBLE'],
#       dtype='object')

# %%
X_train = df_train0[columns0].values
y_train = df_train0['VARIABLE_CIBLE'].values

X_test = df_test0[columns0].values
y_test = df_test0['VARIABLE_CIBLE'].values

#Trials object where the history of search will be stored
trials = Trials()

optimize(trials)
# Out:
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 731.0, 'subsample': 0.8500000000000001, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.9500000000000001}
# 	Score -0.705213727025
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 590.0, 'subsample': 0.75, 'eta': 0.5, 'objective': 'binary:logistic', 'max_depth': 3.0, 'gamma': 0.8}
# 	Score -0.696043266474
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 290.0, 'subsample': 0.75, 'eta': 0.375, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.55}
# 	Score -0.669622802133
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 744.0, 'subsample': 0.8, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8500000000000001}
# 	Score -0.700422935105
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 727.0, 'subsample': 0.55, 'eta': 0.35000000000000003, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.5}
# 	Score -0.661064535444
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 788.0, 'subsample': 0.65, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.65}
# 	Score -0.699178115672
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 646.0, 'subsample': 0.9, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.7000000000000001}
# 	Score -0.704901472382
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 656.0, 'subsample': 0.65, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.55}
# 	Score -0.699239916936
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 947.0, 'subsample': 0.55, 'eta': 0.42500000000000004, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.9}
# 	Score -0.644926224124
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 744.0, 'subsample': 0.7000000000000001, 'eta': 0.30000000000000004, 'objective': 'binary:logistic', 'max_depth': 2.0, 'gamma': 0.8}
# 	Score -0.697621144632
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 912.0, 'subsample': 0.7000000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.8500000000000001}
# 	Score -0.70368825404
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 501.0, 'subsample': 0.6000000000000001, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.9}
# 	Score -0.674113248115
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 141.0, 'subsample': 0.9500000000000001, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.55}
# 	Score -0.700418916731
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 503.0, 'subsample': 0.7000000000000001, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.9}
# 	Score -0.702847547884
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 345.0, 'subsample': 0.9, 'eta': 0.25, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.7000000000000001}
# 	Score -0.695364123201
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 295.0, 'subsample': 0.7000000000000001, 'eta': 0.45, 'objective': 'binary:logistic', 'max_depth': 3.0, 'gamma': 0.8}
# 	Score -0.698206930741
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 129.0, 'subsample': 0.6000000000000001, 'eta': 0.45, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.9}
# 	Score -0.672405417204
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 753.0, 'subsample': 0.8500000000000001, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.7000000000000001}
# 	Score -0.702985812148
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 896.0, 'subsample': 1.0, 'eta': 0.5, 'objective': 'binary:logistic', 'max_depth': 3.0, 'gamma': 0.9500000000000001}
# 	Score -0.698288104439
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 348.0, 'subsample': 0.55, 'eta': 0.35000000000000003, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.75}
# 	Score -0.678211245495
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 597.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 1.0}
# 	Score -0.705593455294
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 442.0, 'subsample': 1.0, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 1.0}
# 	Score -0.703792598016
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 843.0, 'subsample': 0.8500000000000001, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 1.0}
# 	Score -0.707360238635
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 844.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.9500000000000001}
# 	Score -0.707278179195
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 866.0, 'subsample': 0.9500000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 1.0}
# 	Score -0.70973422857
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 989.0, 'subsample': 0.8, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 1.0}
# 	Score -0.706994018829
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 997.0, 'subsample': 0.9500000000000001, 'eta': 0.275, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.9500000000000001}
# 	Score -0.697356638691
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 831.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 1.0, 'gamma': 1.0}
# 	Score -0.675679846625
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 862.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.9500000000000001}
# 	Score -0.707985460129
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 686.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.9500000000000001}
# 	Score -0.707187370797
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 939.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 1.0, 'gamma': 0.8500000000000001}
# 	Score -0.667873328713
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 996.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.6000000000000001}
# 	Score -0.70629118468
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 595.0, 'subsample': 0.8, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 2.0, 'gamma': 0.75}
# 	Score -0.690494362898
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 875.0, 'subsample': 1.0, 'eta': 0.30000000000000004, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.8500000000000001}
# 	Score -0.696699980601
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 780.0, 'subsample': 0.75, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.8}
# 	Score -0.685583023355
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 710.0, 'subsample': 0.9, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 2.0, 'gamma': 0.9}
# 	Score -0.695023203068
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 801.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.9500000000000001}
# 	Score -0.708821479085
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 809.0, 'subsample': 0.9500000000000001, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.65}
# 	Score -0.694255120492
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 528.0, 'subsample': 0.75, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.8500000000000001}
# 	Score -0.708379597063
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 635.0, 'subsample': 1.0, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.9500000000000001}
# 	Score -0.707341690482
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 431.0, 'subsample': 0.8, 'eta': 0.375, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.5}
# 	Score -0.668777585925
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 959.0, 'subsample': 0.9, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.8}
# 	Score -0.693177185622
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 665.0, 'subsample': 0.5, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.9}
# 	Score -0.702063966639
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 777.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.65}
# 	Score -0.69626731933
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 928.0, 'subsample': 0.65, 'eta': 0.325, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.8500000000000001}
# 	Score -0.671706711695
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 711.0, 'subsample': 0.9500000000000001, 'eta': 0.25, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 1.0}
# 	Score -0.697210232836
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 620.0, 'subsample': 0.75, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.75}
# 	Score -0.70257427491
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 573.0, 'subsample': 0.8, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.8}
# 	Score -0.70745411459
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 213.0, 'subsample': 0.9, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.9}
# 	Score -0.706717338461
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 897.0, 'subsample': 0.7000000000000001, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 3.0, 'gamma': 0.9500000000000001}
# 	Score -0.701529072711
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 423.0, 'subsample': 1.0, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 1.0}
# 	Score -0.705935393126
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 758.0, 'subsample': 0.8500000000000001, 'eta': 0.45, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.6000000000000001}
# 	Score -0.667504800557
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 968.0, 'subsample': 0.65, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.7000000000000001}
# 	Score -0.706467349645
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 809.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.9}
# 	Score -0.703813333407
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 549.0, 'subsample': 0.9, 'eta': 0.375, 'objective': 'binary:logistic', 'max_depth': 3.0, 'gamma': 0.9500000000000001}
# 	Score -0.701312322704
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 681.0, 'subsample': 0.75, 'eta': 0.4, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 1.0}
# 	Score -0.695018015153
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 723.0, 'subsample': 0.6000000000000001, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.8500000000000001}
# 	Score -0.70589780876
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 474.0, 'subsample': 0.8500000000000001, 'eta': 0.275, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.6000000000000001}
# 	Score -0.678589983179
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 390.0, 'subsample': 1.0, 'eta': 0.47500000000000003, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.55}
# 	Score -0.682704972337
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 871.0, 'subsample': 0.8, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.9}
# 	Score -0.708286259783
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 179.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.75}
# 	Score -0.700804964494
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 815.0, 'subsample': 0.9, 'eta': 0.30000000000000004, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 1.0}
# 	Score -0.690440735764
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 918.0, 'subsample': 0.5, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.9500000000000001}
# 	Score -0.70332109788
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 748.0, 'subsample': 0.8500000000000001, 'eta': 0.325, 'objective': 'binary:logistic', 'max_depth': 2.0, 'gamma': 0.8}
# 	Score -0.698349254954
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 254.0, 'subsample': 0.8, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.7000000000000001}
# 	Score -0.703014624057
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 499.0, 'subsample': 0.75, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.8500000000000001}
# 	Score -0.707651519278
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 559.0, 'subsample': 0.7000000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.8500000000000001}
# 	Score -0.706111346598
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 524.0, 'subsample': 0.65, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.9}
# 	Score -0.701437886517
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 338.0, 'subsample': 0.7000000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.9500000000000001}
# 	Score -0.708200579648
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 620.0, 'subsample': 0.75, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.9}
# 	Score -0.705117568025
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 468.0, 'subsample': 0.8, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.8}
# 	Score -0.70798949658
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 392.0, 'subsample': 0.75, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.8500000000000001}
# 	Score -0.699404077392
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 692.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.9500000000000001}
# 	Score -0.703557189591
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 527.0, 'subsample': 0.55, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 1.0}
# 	Score -0.705520808214
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 648.0, 'subsample': 0.9, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 1.0}
# 	Score -0.704824919001
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 895.0, 'subsample': 0.6000000000000001, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.9}
# 	Score -0.694198953629
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 305.0, 'subsample': 0.7000000000000001, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.9500000000000001}
# 	Score -0.690822953147
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 606.0, 'subsample': 0.8500000000000001, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.8}
# 	Score -0.709450921409
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 848.0, 'subsample': 0.9, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.75}
# 	Score -0.708660979092
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 103.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.7000000000000001}
# 	Score -0.705328441408
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 786.0, 'subsample': 1.0, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.8}
# 	Score -0.705896874212
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 984.0, 'subsample': 0.8500000000000001, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.65}
# 	Score -0.707913319187
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 589.0, 'subsample': 0.9500000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.75}
# 	Score -0.706484690296
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 768.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.7000000000000001}
# 	Score -0.710234621959
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 769.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.65}
# 	Score -0.709812510051
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 770.0, 'subsample': 1.0, 'eta': 0.25, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.5}
# 	Score -0.690346487435
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 731.0, 'subsample': 1.0, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.6000000000000001}
# 	Score -0.706923016698
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 669.0, 'subsample': 1.0, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.7000000000000001}
# 	Score -0.70149577425
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 954.0, 'subsample': 0.9500000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.65}
# 	Score -0.709300764709
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 834.0, 'subsample': 0.9, 'eta': 0.4, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.6000000000000001}
# 	Score -0.668089169479
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 890.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.55}
# 	Score -0.697533136262
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 852.0, 'subsample': 0.9500000000000001, 'eta': 0.5, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.65}
# 	Score -0.669369751181
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 705.0, 'subsample': 1.0, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.55}
# 	Score -0.696398810382
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 825.0, 'subsample': 1.0, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.7000000000000001}
# 	Score -0.703877294797
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 799.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.65}
# 	Score -0.709874403505
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 795.0, 'subsample': 0.9, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.65}
# 	Score -0.706042182833
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 633.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.6000000000000001}
# 	Score -0.711073950696
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 627.0, 'subsample': 0.8, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.5}
# 	Score -0.704355725409
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 655.0, 'subsample': 0.8500000000000001, 'eta': 0.47500000000000003, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.6000000000000001}
# 	Score -0.664467896303
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 721.0, 'subsample': 0.9, 'eta': 0.275, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.6000000000000001}
# 	Score -0.68137860141
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 739.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.55}
# 	Score -0.711274945348
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 579.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.55}
# 	Score -0.710855315325
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 546.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.55}
# 	Score -0.710923837379
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 463.0, 'subsample': 0.8, 'eta': 0.35000000000000003, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.55}
# 	Score -0.670034279718
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 486.0, 'subsample': 0.75, 'eta': 0.325, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.5}
# 	Score -0.670951701942
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 383.0, 'subsample': 0.65, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.5}
# 	Score -0.687101970774
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 545.0, 'subsample': 0.7000000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.55}
# 	Score -0.701617760752
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 450.0, 'subsample': 0.75, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.5}
# 	Score -0.710238808443
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 418.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.55}
# 	Score -0.699430501414
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 513.0, 'subsample': 0.7000000000000001, 'eta': 0.42500000000000004, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.6000000000000001}
# 	Score -0.658868951942
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 558.0, 'subsample': 0.8500000000000001, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.5}
# 	Score -0.688498689468
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 250.0, 'subsample': 0.75, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.5}
# 	Score -0.709325252753
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 683.0, 'subsample': 0.8, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.55}
# 	Score -0.700557059882
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 324.0, 'subsample': 0.8500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.6000000000000001}
# 	Score -0.70440182374
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 364.0, 'subsample': 0.7000000000000001, 'eta': 0.25, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.6000000000000001}
# 	Score -0.676960083068
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 608.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.55}
# 	Score -0.70210221983
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 411.0, 'subsample': 0.75, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.55}
# 	Score -0.694898112855
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 741.0, 'subsample': 0.65, 'eta': 0.30000000000000004, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.5}
# 	Score -0.666970354923
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 572.0, 'subsample': 0.8500000000000001, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.65}
# 	Score -0.710470679325
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 482.0, 'subsample': 0.8, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.5}
# 	Score -0.703180227005
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 642.0, 'subsample': 0.6000000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.6000000000000001}
# 	Score -0.705813927223
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 506.0, 'subsample': 0.75, 'eta': 0.375, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.55}
# 	Score -0.671504939759
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 695.0, 'subsample': 0.8500000000000001, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 1.0, 'gamma': 0.7000000000000001}
# 	Score -0.671799450648
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 541.0, 'subsample': 0.7000000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.6000000000000001}
# 	Score -0.690843395701
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 445.0, 'subsample': 0.55, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.5}
# 	Score -0.682704361356
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 662.0, 'subsample': 0.8500000000000001, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.55}
# 	Score -0.686196990507
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 628.0, 'subsample': 0.8, 'eta': 0.275, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.65}
# 	Score -0.676740513149
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 672.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.6000000000000001}
# 	Score -0.711943463338
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 938.0, 'subsample': 0.9, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.75}
# 	Score -0.696778077703
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 738.0, 'subsample': 0.9500000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.65}
# 	Score -0.711205414633
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 875.0, 'subsample': 0.9500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.7000000000000001}
# 	Score -0.709527221721
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 911.0, 'subsample': 0.9500000000000001, 'eta': 0.35000000000000003, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.65}
# 	Score -0.687910900498
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 823.0, 'subsample': 0.9500000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.75}
# 	Score -0.705442570116
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 708.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.65}
# 	Score -0.710349804519
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 746.0, 'subsample': 0.9500000000000001, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 3.0, 'gamma': 0.7000000000000001}
# 	Score -0.701489888587
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 732.0, 'subsample': 1.0, 'eta': 0.4, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.7000000000000001}
# 	Score -0.694586881334
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 597.0, 'subsample': 0.9, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.65}
# 	Score -0.70382257585
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 859.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.6000000000000001}
# 	Score -0.711159419337
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 974.0, 'subsample': 0.9500000000000001, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.6000000000000001}
# 	Score -0.701942413969
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 672.0, 'subsample': 0.8500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 2.0, 'gamma': 0.65}
# 	Score -0.696060836695
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 761.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.75}
# 	Score -0.703644442369
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 785.0, 'subsample': 0.9500000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.6000000000000001}
# 	Score -0.710307531146
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 882.0, 'subsample': 0.8500000000000001, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.65}
# 	Score -0.70220340948
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 932.0, 'subsample': 1.0, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.7000000000000001}
# 	Score -0.705009164099
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 915.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.55}
# 	Score -0.703742215588
#
#
# Training with params :
# ...
# 	Score -0.699105927732
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 534.0, 'subsample': 0.75, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.8}
# 	Score -0.700721984968
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 562.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.65}
# 	Score -0.701725801343
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 587.0, 'subsample': 0.9500000000000001, 'eta': 0.375, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.7000000000000001}
# 	Score -0.681482771852
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 747.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.9}
# 	Score -0.706671666732
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 711.0, 'subsample': 1.0, 'eta': 0.275, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8}
# 	Score -0.691869648453
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 639.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.75}
# 	Score -0.710554074608
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 892.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.7000000000000001}
# 	Score -0.710501101837
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 434.0, 'subsample': 0.8500000000000001, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.6000000000000001}
# 	Score -0.69124048089
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 728.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 2.0, 'gamma': 0.65}
# 	Score -0.688463896092
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 795.0, 'subsample': 0.9500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8}
# 	Score -0.705824646504
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 276.0, 'subsample': 0.75, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.75}
# 	Score -0.702885166595
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 676.0, 'subsample': 0.7000000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.7000000000000001}
# 	Score -0.694210851489
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 606.0, 'subsample': 0.8, 'eta': 0.4, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.6000000000000001}
# 	Score -0.662866350769
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 325.0, 'subsample': 1.0, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.65}
# 	Score -0.710408747911
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 510.0, 'subsample': 0.9, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.7000000000000001}
# 	Score -0.693275942195
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 812.0, 'subsample': 0.8500000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 1.0, 'gamma': 0.8500000000000001}
# 	Score -0.66655755234
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 928.0, 'subsample': 0.8500000000000001, 'eta': 0.25, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.75}
# 	Score -0.685803916463
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 763.0, 'subsample': 1.0, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.6000000000000001}
# 	Score -0.707552929008
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 965.0, 'subsample': 0.8, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.65}
# 	Score -0.703072450329
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 831.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.7000000000000001}
# 	Score -0.712033955399
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 875.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.8}
# 	Score -0.711756698396
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 984.0, 'subsample': 0.9, 'eta': 0.325, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.9}
# 	Score -0.679669897411
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 877.0, 'subsample': 0.9, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.8500000000000001}
# 	Score -0.705134017512
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 909.0, 'subsample': 0.9500000000000001, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.8500000000000001}
# 	Score -0.70461150589
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 965.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.9}
# 	Score -0.711520545225
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 945.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.8}
# 	Score -0.699470229636
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 867.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8500000000000001}
# 	Score -0.694984720307
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 890.0, 'subsample': 0.9, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.8}
# 	Score -0.706970009809
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 835.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.9}
# 	Score -0.709344834872
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 849.0, 'subsample': 0.9500000000000001, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8}
# 	Score -0.686910308945
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 102.0, 'subsample': 0.8500000000000001, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.8500000000000001}
# 	Score -0.705733812799
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 214.0, 'subsample': 0.8, 'eta': 0.42500000000000004, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.8}
# 	Score -0.67943684072
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 937.0, 'subsample': 0.9, 'eta': 0.30000000000000004, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.75}
# 	Score -0.68261240511
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 997.0, 'subsample': 0.9500000000000001, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.8}
# 	Score -0.702759158104
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 832.0, 'subsample': 0.8500000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.9}
# 	Score -0.709278548863
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 924.0, 'subsample': 0.8500000000000001, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.75}
# 	Score -0.688040607413
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 983.0, 'subsample': 0.75, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8500000000000001}
# 	Score -0.708661342427
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 701.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8}
# 	Score -0.699421436119
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 777.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.75}
# 	Score -0.710182847651
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 907.0, 'subsample': 0.9, 'eta': 0.45, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.9500000000000001}
# 	Score -0.672322482869
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 741.0, 'subsample': 0.9500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.75}
# 	Score -0.707234349447
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 861.0, 'subsample': 0.9, 'eta': 0.35000000000000003, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.8}
# 	Score -0.68130106106
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 821.0, 'subsample': 0.8500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8500000000000001}
# 	Score -0.692092674572
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 952.0, 'subsample': 0.9500000000000001, 'eta': 0.47500000000000003, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.7000000000000001}
# 	Score -0.665918149942
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 806.0, 'subsample': 0.8, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.55}
# 	Score -0.693791275694
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 655.0, 'subsample': 0.65, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.8500000000000001}
# 	Score -0.71056830251
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 760.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.75}
# 	Score -0.707796789938
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 620.0, 'subsample': 1.0, 'eta': 0.275, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.8}
# 	Score -0.696607646559
#
#
# {'colsample_bytree': 0.55, 'min_child_weight': 2.0, 'n_estimators': 590.0, 'subsample': 0.9, 'eta': 0.025, 'max_depth': 12.0, 'gamma': 0.75}

# %% [markdown]
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 590.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.75}
# 	Score -0.712056925029
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 831.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.7000000000000001}
# 	Score -0.712033955399
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.3265408761400996, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 672.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.6000000000000001}
# 	Score -0.711943463338
#
#
# Best results :
# {'colsample_bytree': 0.55, 'min_child_weight': 2.0, 'n_estimators': 590.0, 'subsample': 0.9, 'eta': 0.025, 'max_depth': 12.0, 'gamma': 0.75}

# %% [markdown]
# ## Optimization on df1

# %%
# Columns selected by RFECV
columns1 = ['APP_NB', 'APP_NB_PAYS', 'APP_NB_TYPE', 'COUNTRY', 'FIRST_CLASSE', 'FISRT_APP_COUNTRY', 
            'FISRT_APP_TYPE', 'FISRT_INV_COUNTRY', 'FISRT_INV_TYPE', 'IDX_ORIGIN', 'IDX_RADIC', 'INV_NB',
            'INV_NB_PAYS', 'INV_NB_TYPE', 'LANGUAGE_OF_FILLING', 'MAIN_IPC', 'NB_BACKWARD', 'NB_BACKWARD_AUTRE',
            'NB_BACKWARD_NPL', 'NB_BACKWARD_PL', 'NB_BACKWARD_XY', 'NB_CLASSES', 'NB_FIELDS', 'NB_ROOT_CLASSES',
            'NB_SECTORS', 'SOURCE_BEGIN_MONTH', 'SOURCE_IDX_RAD', 'TECHNOLOGIE_FIELD', 'TECHNOLOGIE_SECTOR',
            'cited_age_max', 'cited_age_mean', 'cited_age_median', 'cited_age_min', 'cited_age_std', 'cited_n',
            'oecd_NB_BACKWARD_NPL', 'oecd_NB_BACKWARD_PL', 'oecd_NB_ROOT_CLASSES', 'pct_NB_IPC', 'pct_NB_IPC_LY',
            'filing-begin', 'pub-filing', 'pub_year', 'VARIABLE_CIBLE']

df_train1, df_test1 = train_test_split(df1_train[columns1], test_size=0.2, random_state=42)

columns1.remove('VARIABLE_CIBLE')

test_size = len(df_test1)
train_size = len(df_train1)
# rescale weight to make it same as test set
weight = np.ones(train_size) * float(test_size) / float(train_size)

# computing weights to balance the repartition of 'VARIABLE_CIBLE'values
sum_wpos = sum( weight[i] for i in range(train_size) if df_train1['VARIABLE_CIBLE'].iloc[i] == 1.0  )
sum_wneg = sum( weight[i] for i in range(train_size) if df_train1['VARIABLE_CIBLE'].iloc[i] == 0.0  )

# %%
X_train = df_train1[columns1].values
y_train = df_train1['VARIABLE_CIBLE'].values

X_test = df_test1[columns1].values
y_test = df_test1['VARIABLE_CIBLE'].values

#Trials object where the history of search will be stored
trials = Trials()

optimize(trials)
# Out:
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 702.0, 'subsample': 0.8500000000000001, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.9}
# 	Score -0.690912980965
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 427.0, 'subsample': 0.5, 'eta': 0.275, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.65}
# 	Score -0.639884770707
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 802.0, 'subsample': 0.55, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 2.0, 'gamma': 0.5}
# 	Score -0.690685349984
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 923.0, 'subsample': 0.5, 'eta': 0.275, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.8500000000000001}
# 	Score -0.641581096254
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 801.0, 'subsample': 0.7000000000000001, 'eta': 0.5, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.7000000000000001}
# 	Score -0.633240505844
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 248.0, 'subsample': 0.8500000000000001, 'eta': 0.35000000000000003, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.5}
# 	Score -0.655830454027
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 432.0, 'subsample': 0.75, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.6000000000000001}
# 	Score -0.690983596256
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 518.0, 'subsample': 0.9500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.7000000000000001}
# 	Score -0.694524011418
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 586.0, 'subsample': 1.0, 'eta': 0.35000000000000003, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.5}
# 	Score -0.664584829968
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 297.0, 'subsample': 0.7000000000000001, 'eta': 0.30000000000000004, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.9}
# 	Score -0.679978433503
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 802.0, 'subsample': 0.9, 'eta': 0.30000000000000004, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.7000000000000001}
# 	Score -0.659179072648
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 764.0, 'subsample': 0.6000000000000001, 'eta': 0.375, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.6000000000000001}
# 	Score -0.662833798923
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 344.0, 'subsample': 1.0, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.75}
# 	Score -0.685012199669
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 178.0, 'subsample': 0.9500000000000001, 'eta': 0.275, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.75}
# 	Score -0.675299408335
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 730.0, 'subsample': 0.6000000000000001, 'eta': 0.375, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.75}
# 	Score -0.664122298876
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 338.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.9}
# 	Score -0.683086241949
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 666.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.8500000000000001}
# 	Score -0.691624557668
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 823.0, 'subsample': 0.6000000000000001, 'eta': 0.42500000000000004, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.55}
# 	Score -0.636080272934
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 350.0, 'subsample': 0.75, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.8500000000000001}
# 	Score -0.69466033565
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 365.0, 'subsample': 0.75, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.9500000000000001}
# 	Score -0.680275108745
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 110.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8}
# 	Score -0.696183324253
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 211.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8}
# 	Score -0.698272245132
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 100.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 1.0, 'gamma': 0.8}
# 	Score -0.648215922471
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 106.0, 'subsample': 0.8, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8}
# 	Score -0.665668647195
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 183.0, 'subsample': 0.7000000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8}
# 	Score -0.682321194128
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 182.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 1.0}
# 	Score -0.699017094
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 220.0, 'subsample': 0.65, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 1.0}
# 	Score -0.684669272564
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 500.0, 'subsample': 0.9, 'eta': 0.5, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 1.0}
# 	Score -0.644255861587
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 618.0, 'subsample': 0.9, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.9500000000000001}
# 	Score -0.695677726998
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 159.0, 'subsample': 0.8, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.9500000000000001}
# 	Score -0.684172789776
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 266.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.65}
# 	Score -0.690482069963
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 435.0, 'subsample': 0.65, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.9500000000000001}
# 	Score -0.674338044145
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 921.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 1.0}
# 	Score -0.699925947146
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 991.0, 'subsample': 0.7000000000000001, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 1.0}
# 	Score -0.667546931644
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 900.0, 'subsample': 0.8500000000000001, 'eta': 0.42500000000000004, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 1.0}
# 	Score -0.654760221219
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 997.0, 'subsample': 0.65, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.9}
# 	Score -0.691951593682
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 896.0, 'subsample': 0.75, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.8500000000000001}
# 	Score -0.688256301176
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 667.0, 'subsample': 0.9, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.9500000000000001}
# 	Score -0.669486735622
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 513.0, 'subsample': 0.8500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.9}
# 	Score -0.675729621102
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 406.0, 'subsample': 0.75, 'eta': 0.45, 'objective': 'binary:logistic', 'max_depth': 2.0, 'gamma': 1.0}
# 	Score -0.68740217223
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 857.0, 'subsample': 0.5, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.9}
# 	Score -0.684089531436
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 575.0, 'subsample': 0.55, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.65}
# 	Score -0.690731028295
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 968.0, 'subsample': 0.7000000000000001, 'eta': 0.30000000000000004, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.8500000000000001}
# 	Score -0.663966561207
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 466.0, 'subsample': 0.9500000000000001, 'eta': 0.25, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.9500000000000001}
# 	Score -0.689379961461
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 619.0, 'subsample': 0.9, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.55}
# 	Score -0.672888133359
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 755.0, 'subsample': 0.8, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.7000000000000001}
# 	Score -0.674711107589
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 699.0, 'subsample': 1.0, 'eta': 0.35000000000000003, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 1.0}
# 	Score -0.662365245551
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 953.0, 'subsample': 0.8500000000000001, 'eta': 0.325, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.9}
# 	Score -0.65454037681
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 298.0, 'subsample': 0.9500000000000001, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 3.0, 'gamma': 0.9500000000000001}
# 	Score -0.694099852104
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 547.0, 'subsample': 0.7000000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.8500000000000001}
# 	Score -0.696644215738
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 844.0, 'subsample': 0.75, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.6000000000000001}
# 	Score -0.68656702656
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 392.0, 'subsample': 0.55, 'eta': 0.25, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.7000000000000001}
# 	Score -0.651274499086
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 140.0, 'subsample': 0.65, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.9}
# 	Score -0.697553654903
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 777.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.55}
# 	Score -0.685528320329
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 307.0, 'subsample': 0.8, 'eta': 0.45, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.75}
# 	Score -0.647995211501
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 469.0, 'subsample': 0.7000000000000001, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 1.0}
# 	Score -0.674407761705
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 705.0, 'subsample': 1.0, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.65}
# 	Score -0.69395826617
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 264.0, 'subsample': 0.6000000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.9500000000000001}
# 	Score -0.690516426886
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 629.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.75}
# 	Score -0.700023014338
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 644.0, 'subsample': 0.9, 'eta': 0.5, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.5}
# 	Score -0.648580476171
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 794.0, 'subsample': 0.9500000000000001, 'eta': 0.375, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.6000000000000001}
# 	Score -0.659084044054
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 874.0, 'subsample': 0.9500000000000001, 'eta': 0.275, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.7000000000000001}
# 	Score -0.668457723641
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 726.0, 'subsample': 0.9, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.5}
# 	Score -0.66974460269
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 932.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.75}
# 	Score -0.697160186776
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 550.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.8}
# 	Score -0.673632084496
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 599.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.8500000000000001}
# 	Score -0.698647309769
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 820.0, 'subsample': 0.75, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 1.0}
# 	Score -0.681815278927
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 233.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.55}
# 	Score -0.697978736886
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 469.0, 'subsample': 0.8500000000000001, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.9500000000000001}
# 	Score -0.695837117936
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 367.0, 'subsample': 0.9, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.65}
# 	Score -0.679582184902
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 547.0, 'subsample': 0.75, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.9}
# 	Score -0.682283464479
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 672.0, 'subsample': 0.8500000000000001, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.8500000000000001}
# 	Score -0.6996686848
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 672.0, 'subsample': 0.9500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.8}
# 	Score -0.694619251976
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 748.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.7000000000000001}
# 	Score -0.694991187022
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 628.0, 'subsample': 0.8500000000000001, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.75}
# 	Score -0.699528732238
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 694.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.8}
# 	Score -0.685904943527
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 906.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.8500000000000001}
# 	Score -0.687874559663
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 594.0, 'subsample': 0.9, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.75}
# 	Score -0.689353833741
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 831.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.8}
# 	Score -0.696238815266
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 728.0, 'subsample': 0.9500000000000001, 'eta': 0.2, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.75}
# 	Score -0.674996617299
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 495.0, 'subsample': 0.8, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.8500000000000001}
# 	Score -0.683832661847
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 657.0, 'subsample': 0.75, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.7000000000000001}
# 	Score -0.697539515636
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 874.0, 'subsample': 0.8500000000000001, 'eta': 0.17500000000000002, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.8}
# 	Score -0.668063469999
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 783.0, 'subsample': 0.9, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 6.0, 'gamma': 0.65}
# 	Score -0.693756444962
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 436.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.7000000000000001}
# 	Score -0.699446109791
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 571.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'binary:logistic', 'max_depth': 5.0, 'gamma': 0.9}
# 	Score -0.697119676653
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 981.0, 'subsample': 0.9500000000000001, 'eta': 0.325, 'objective': 'binary:logistic', 'max_depth': 10.0, 'gamma': 0.75}
# 	Score -0.660414213699
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 941.0, 'subsample': 0.65, 'eta': 0.47500000000000003, 'objective': 'binary:logistic', 'max_depth': 7.0, 'gamma': 0.8500000000000001}
# 	Score -0.639473111054
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 532.0, 'subsample': 0.7000000000000001, 'eta': 0.225, 'objective': 'binary:logistic', 'max_depth': 4.0, 'gamma': 0.6000000000000001}
# 	Score -0.683487365729
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 808.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.8}
# 	Score -0.686818166879
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 768.0, 'subsample': 0.9, 'eta': 0.25, 'objective': 'binary:logistic', 'max_depth': 8.0, 'gamma': 0.9}
# 	Score -0.669111259525
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 637.0, 'subsample': 0.75, 'eta': 0.4, 'objective': 'binary:logistic', 'max_depth': 13.0, 'gamma': 0.7000000000000001}
# 	Score -0.642398143911
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 694.0, 'subsample': 0.7000000000000001, 'eta': 0.125, 'objective': 'binary:logistic', 'max_depth': 3.0, 'gamma': 0.75}
# 	Score -0.691969585713
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 496.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.65}
# 	Score -0.681611363013
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 610.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'binary:logistic', 'max_depth': 11.0, 'gamma': 0.8}
# 	Score -0.682859203222
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 567.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'binary:logistic', 'max_depth': 12.0, 'gamma': 0.8500000000000001}
# 	Score -0.688383099481
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 0, 'eval_metric': 'auc', 'scale_pos_weight': 1.5966246815738532, 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 913.0, 'subsample': 0.5, 'eta': 0.05, 'objective': 'binary:logistic', 'max_depth': 9.0, 'gamma': 0.9500000000000001}
# 	Score -0.686667921579
