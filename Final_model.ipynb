# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler, Imputer, OneHotEncoder, LabelEncoder
from sklearn.cross_validation import train_test_split
import numpy as np
import seaborn as sns
import operator
import math
from data_science import *
import xgboost as xgb
from hyperopt import fmin, tpe, hp, fmin, STATUS_OK, Trials
from hyperopt.mongoexp import MongoTrials

# %matplotlib inline

# %% [markdown]
# # Preprocessings

# %%
# train and test data are imported in a single dataframe to do the preprocessings
# using import_data from utils/data_science.py module
df_all = import_data('data/train.csv', 'data/test.csv', 'VARIABLE_CIBLE', na_values='(MISSING)')

# creating two subsets of data
df_all0 = df_all[df_all.SOURCE_CITED_AGE == 'IMPUT']
df_all1 = df_all[df_all.SOURCE_CITED_AGE == 'CALC']

date_columns = ['PRIORITY_MONTH', 'FILING_MONTH', 'PUBLICATION_MONTH', 'BEGIN_MONTH']

# preprocessings using the Preprocessing class in the utils/data_science.py module
preproc = Preprocessings(date_columns=date_columns)

df0 = preproc.datetime_processings(df_all0, format='%m/%Y')
df0 = preproc.cat_to_codes(df0)
df0 = df0.fillna(df0.median())
df0 = df0.dropna(axis=1, how='all')


preproc = Preprocessings(date_columns=date_columns)

df1 = preproc.datetime_processings(df_all1, format='%m/%Y')
df1 = preproc.cat_to_codes(df1)
df1 = df1.fillna(df1.median())
df1 = df1.dropna(axis=1, how='all')

# splitting the train and test data (re_split is in utils.data_science.py)
df0_train, df0_eval = re_split(df0, 'VARIABLE_CIBLE')
df1_train, df1_eval = re_split(df1, 'VARIABLE_CIBLE')
# Out:
# Index([u'COUNTRY', u'FIRST_CLASSE', u'FISRT_APP_COUNTRY', u'FISRT_APP_TYPE',
#        u'FISRT_INV_COUNTRY', u'FISRT_INV_TYPE', u'LANGUAGE_OF_FILLING',
#        u'MAIN_IPC', u'SOURCE_BEGIN_MONTH', u'SOURCE_CITED_AGE',
#        u'SOURCE_IDX_ORI', u'SOURCE_IDX_RAD', u'TECHNOLOGIE_FIELD',
#        u'TECHNOLOGIE_SECTOR', u'VARIABLE_CIBLE', u'VOIE_DEPOT'],
#       dtype='object')
# Index([u'COUNTRY', u'FIRST_CLASSE', u'FISRT_APP_COUNTRY', u'FISRT_APP_TYPE',
#        u'FISRT_INV_COUNTRY', u'FISRT_INV_TYPE', u'LANGUAGE_OF_FILLING',
#        u'MAIN_IPC', u'SOURCE_BEGIN_MONTH', u'SOURCE_CITED_AGE',
#        u'SOURCE_IDX_ORI', u'SOURCE_IDX_RAD', u'TECHNOLOGIE_FIELD',
#        u'TECHNOLOGIE_SECTOR', u'VARIABLE_CIBLE', u'VOIE_DEPOT'],
#       dtype='object')
# /home/maxime/local/anaconda3/envs/env-python2.7/lib/python2.7/site-packages/pandas/core/frame.py:2320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %% [markdown]
# # Training the model

# %% [markdown]
# ## on df0

# %%
# columns selected for df0_train after RFECV
columns0 = ['APP_NB', 'APP_NB_PAYS', 'APP_NB_TYPE', 'COUNTRY', 'FIRST_CLASSE', 'FISRT_APP_COUNTRY', 
           'FISRT_APP_TYPE', 'FISRT_INV_COUNTRY', 'FISRT_INV_TYPE', 'INV_NB', 'INV_NB_PAYS', 
           'INV_NB_TYPE', 'LANGUAGE_OF_FILLING', 'MAIN_IPC', 'NB_BACKWARD', 'NB_BACKWARD_AUTRE', 
           'NB_BACKWARD_NPL', 'NB_BACKWARD_PL', 'NB_BACKWARD_XY', 'NB_CLASSES', 'NB_FIELDS', 
           'NB_ROOT_CLASSES', 'NB_SECTORS', 'TECHNOLOGIE_FIELD', 'TECHNOLOGIE_SECTOR', 'VOIE_DEPOT', 
           'oecd_NB_BACKWARD_NPL', 'oecd_NB_BACKWARD_PL', 'oecd_NB_ROOT_CLASSES', 'pct_NB_IPC', 'pct_NB_IPC_LY',
           'filing-begin', 'pub-filing', 'pub_year', 'VARIABLE_CIBLE']

removed = [col for col in df0_train.columns if col not in columns0]
print(removed)

df_train0, df_test0 = train_test_split(df0_train[columns0], test_size=0.2, random_state=42)

columns0.remove('VARIABLE_CIBLE')


test_size = len(df_test0)
train_size = len(df_train0)
# rescale weight to make it same as test set
weight = np.ones(train_size) * float(test_size) / float(train_size)

print(df_train0.columns)

# computing weights to balance the repartition of 'VARIABLE_CIBLE'values
sum_wpos = sum( weight[i] for i in range(train_size) if df_train0['VARIABLE_CIBLE'].iloc[i] == 1.0  )
sum_wneg = sum( weight[i] for i in range(train_size) if df_train0['VARIABLE_CIBLE'].iloc[i] == 0.0  )

# construct xgboost.DMatrix from numpy array, treat -999.0 as missing value
dtrain0 = xgb.DMatrix( df_train0[columns0].values, label=df_train0['VARIABLE_CIBLE'].values, weight=weight )
dtest0 = xgb.DMatrix( df_test0[columns0].values, label=df_test0['VARIABLE_CIBLE'].values)
# Out:
# ['IDX_ORIGIN', 'IDX_RADIC', 'NB_BACKWARD_I', 'SOURCE_BEGIN_MONTH', 'SOURCE_CITED_AGE', 'SOURCE_IDX_ORI', 'SOURCE_IDX_RAD', 'cited_age_max', 'cited_age_mean', 'cited_age_median', 'cited_age_min', 'index_origin']
# Index([u'APP_NB', u'APP_NB_PAYS', u'APP_NB_TYPE', u'COUNTRY', u'FIRST_CLASSE',
#        u'FISRT_APP_COUNTRY', u'FISRT_APP_TYPE', u'FISRT_INV_COUNTRY',
#        u'FISRT_INV_TYPE', u'INV_NB', u'INV_NB_PAYS', u'INV_NB_TYPE',
#        u'LANGUAGE_OF_FILLING', u'MAIN_IPC', u'NB_BACKWARD',
#        u'NB_BACKWARD_AUTRE', u'NB_BACKWARD_NPL', u'NB_BACKWARD_PL',
#        u'NB_BACKWARD_XY', u'NB_CLASSES', u'NB_FIELDS', u'NB_ROOT_CLASSES',
#        u'NB_SECTORS', u'TECHNOLOGIE_FIELD', u'TECHNOLOGIE_SECTOR',
#        u'VOIE_DEPOT', u'oecd_NB_BACKWARD_NPL', u'oecd_NB_BACKWARD_PL',
#        u'oecd_NB_ROOT_CLASSES', u'pct_NB_IPC', u'pct_NB_IPC_LY',
#        u'filing-begin', u'pub-filing', u'pub_year', u'VARIABLE_CIBLE'],
#       dtype='object')

# %%
# Parameters optained with hyperopt
param = {'colsample_bytree': 0.55, 'min_child_weight': 2.0,
         'subsample': 0.9, 'eta': 0.025, 'max_depth': 12.0, 'gamma': 0.75, 'objective': 'binary:logistic',
        'nthread': 6, 'scale_pos_weight': sum_wneg/sum_wpos, 'eval_metric': 'auc', 'silent': 0}


plst = list(param.items())

evallist  = [(dtrain0,'train'), (dtest0,'eval')]



num_round = 590
print ('loading data end, start to boost trees')
bst0 = xgb.train( plst, dtrain0, num_round, evallist)#, early_stopping_rounds=50 );
# save out model
bst0.save_model('df0_xgboost_optimized.model')
# Out:
# [0]	train-auc:0.664510	eval-auc:0.616507
# [1]	train-auc:0.718911	eval-auc:0.664660
# [2]	train-auc:0.726324	eval-auc:0.671996
# [3]	train-auc:0.731837	eval-auc:0.674549
# [4]	train-auc:0.738772	eval-auc:0.679690
# [5]	train-auc:0.739712	eval-auc:0.680703
# [6]	train-auc:0.742091	eval-auc:0.683541
# [7]	train-auc:0.745953	eval-auc:0.687262
# [8]	train-auc:0.748822	eval-auc:0.689131
# [9]	train-auc:0.749418	eval-auc:0.688463
# [10]	train-auc:0.749909	eval-auc:0.688969
# [11]	train-auc:0.752329	eval-auc:0.690325
# [12]	train-auc:0.754652	eval-auc:0.691837
# [13]	train-auc:0.755249	eval-auc:0.692265
# [14]	train-auc:0.756030	eval-auc:0.692718
# [15]	train-auc:0.757039	eval-auc:0.692957
# [16]	train-auc:0.756477	eval-auc:0.692163
# [17]	train-auc:0.757786	eval-auc:0.692609
# [18]	train-auc:0.758530	eval-auc:0.692875
# [19]	train-auc:0.759006	eval-auc:0.693461
# [20]	train-auc:0.759093	eval-auc:0.693412
# [21]	train-auc:0.760736	eval-auc:0.694223
# [22]	train-auc:0.761443	eval-auc:0.694947
# [23]	train-auc:0.761891	eval-auc:0.695098
# [24]	train-auc:0.762631	eval-auc:0.695038
# [25]	train-auc:0.763733	eval-auc:0.695781
# [26]	train-auc:0.764206	eval-auc:0.696360
# [27]	train-auc:0.764045	eval-auc:0.696332
# [28]	train-auc:0.764581	eval-auc:0.696899
# [29]	train-auc:0.765586	eval-auc:0.697626
# [30]	train-auc:0.766025	eval-auc:0.697837
# [31]	train-auc:0.766913	eval-auc:0.698388
# [32]	train-auc:0.767031	eval-auc:0.698486
# [33]	train-auc:0.767939	eval-auc:0.698804
# [34]	train-auc:0.767998	eval-auc:0.698893
# [35]	train-auc:0.768676	eval-auc:0.699298
# [36]	train-auc:0.769109	eval-auc:0.699337
# [37]	train-auc:0.769901	eval-auc:0.699666
# [38]	train-auc:0.770538	eval-auc:0.699714
# [39]	train-auc:0.771011	eval-auc:0.699799
# [40]	train-auc:0.771506	eval-auc:0.699887
# [41]	train-auc:0.771964	eval-auc:0.700229
# [42]	train-auc:0.772415	eval-auc:0.700308
# [43]	train-auc:0.773024	eval-auc:0.700321
# [44]	train-auc:0.773617	eval-auc:0.700517
# [45]	train-auc:0.774292	eval-auc:0.700734
# [46]	train-auc:0.774805	eval-auc:0.700895
# [47]	train-auc:0.775306	eval-auc:0.701197
# [48]	train-auc:0.775890	eval-auc:0.701360
# [49]	train-auc:0.776432	eval-auc:0.701556
# [50]	train-auc:0.777209	eval-auc:0.701803
# [51]	train-auc:0.777819	eval-auc:0.701988
# [52]	train-auc:0.777903	eval-auc:0.701941
# [53]	train-auc:0.778507	eval-auc:0.702125
# [54]	train-auc:0.778983	eval-auc:0.702224
# [55]	train-auc:0.779450	eval-auc:0.702320
# [56]	train-auc:0.779850	eval-auc:0.702463
# [57]	train-auc:0.780331	eval-auc:0.702529
# [58]	train-auc:0.780717	eval-auc:0.702577
# [59]	train-auc:0.781160	eval-auc:0.702664
# [60]	train-auc:0.781139	eval-auc:0.702659
# [61]	train-auc:0.781246	eval-auc:0.702677
# [62]	train-auc:0.781871	eval-auc:0.702823
# [63]	train-auc:0.782475	eval-auc:0.703003
# [64]	train-auc:0.782734	eval-auc:0.702932
# [65]	train-auc:0.783016	eval-auc:0.702950
# [66]	train-auc:0.783354	eval-auc:0.703009
# [67]	train-auc:0.783558	eval-auc:0.703175
# [68]	train-auc:0.783710	eval-auc:0.703194
# [69]	train-auc:0.784178	eval-auc:0.703348
# [70]	train-auc:0.784670	eval-auc:0.703505
# [71]	train-auc:0.785024	eval-auc:0.703631
# [72]	train-auc:0.785486	eval-auc:0.703714
# [73]	train-auc:0.785842	eval-auc:0.703871
# [74]	train-auc:0.786271	eval-auc:0.703950
# [75]	train-auc:0.786601	eval-auc:0.703990
# [76]	train-auc:0.786900	eval-auc:0.704262
# [77]	train-auc:0.787296	eval-auc:0.704238
# [78]	train-auc:0.787578	eval-auc:0.704245
# [79]	train-auc:0.788130	eval-auc:0.704278
# [80]	train-auc:0.788563	eval-auc:0.704438
# [81]	train-auc:0.789026	eval-auc:0.704535
# [82]	train-auc:0.789380	eval-auc:0.704661
# [83]	train-auc:0.789900	eval-auc:0.704805
# [84]	train-auc:0.790068	eval-auc:0.704912
# [85]	train-auc:0.790624	eval-auc:0.705039
# [86]	train-auc:0.790820	eval-auc:0.705011
# [87]	train-auc:0.791270	eval-auc:0.705098
# [88]	train-auc:0.791751	eval-auc:0.705117
# [89]	train-auc:0.792456	eval-auc:0.705249
# [90]	train-auc:0.793108	eval-auc:0.705277
# [91]	train-auc:0.793237	eval-auc:0.705440
# [92]	train-auc:0.793605	eval-auc:0.705549
# [93]	train-auc:0.794075	eval-auc:0.705639
# [94]	train-auc:0.794481	eval-auc:0.705632
# [95]	train-auc:0.795083	eval-auc:0.705703
# [96]	train-auc:0.795300	eval-auc:0.705837
# [97]	train-auc:0.795658	eval-auc:0.705912
# [98]	train-auc:0.795909	eval-auc:0.705921
# [99]	train-auc:0.796532	eval-auc:0.705989
# [100]	train-auc:0.796913	eval-auc:0.706033
# [101]	train-auc:0.797321	eval-auc:0.705985
# [102]	train-auc:0.797714	eval-auc:0.706103
# [103]	train-auc:0.797887	eval-auc:0.706230
# [104]	train-auc:0.798079	eval-auc:0.706209
# [105]	train-auc:0.798321	eval-auc:0.706365
# [106]	train-auc:0.798544	eval-auc:0.706350
# [107]	train-auc:0.798718	eval-auc:0.706460
# [108]	train-auc:0.799034	eval-auc:0.706542
# [109]	train-auc:0.799422	eval-auc:0.706510
# [110]	train-auc:0.799563	eval-auc:0.706599
# [111]	train-auc:0.799775	eval-auc:0.706625
# [112]	train-auc:0.800056	eval-auc:0.706619
# [113]	train-auc:0.800366	eval-auc:0.706690
# [114]	train-auc:0.800602	eval-auc:0.706735
# [115]	train-auc:0.801077	eval-auc:0.706779
# [116]	train-auc:0.801378	eval-auc:0.706869
# [117]	train-auc:0.801501	eval-auc:0.706929
# [118]	train-auc:0.801604	eval-auc:0.707017
# [119]	train-auc:0.801742	eval-auc:0.707091
# [120]	train-auc:0.802106	eval-auc:0.707045
# [121]	train-auc:0.802292	eval-auc:0.707097
# [122]	train-auc:0.802536	eval-auc:0.707195
# [123]	train-auc:0.802754	eval-auc:0.707158
# [124]	train-auc:0.802907	eval-auc:0.707153
# [125]	train-auc:0.803022	eval-auc:0.707185
# [126]	train-auc:0.803255	eval-auc:0.707268
# [127]	train-auc:0.803514	eval-auc:0.707281
# [128]	train-auc:0.803826	eval-auc:0.707309
# [129]	train-auc:0.803979	eval-auc:0.707333
# [130]	train-auc:0.804295	eval-auc:0.707406
# [131]	train-auc:0.804632	eval-auc:0.707486
# [132]	train-auc:0.804959	eval-auc:0.707529
# [133]	train-auc:0.805215	eval-auc:0.707618
# [134]	train-auc:0.805447	eval-auc:0.707672
# [135]	train-auc:0.805811	eval-auc:0.707697
# [136]	train-auc:0.806229	eval-auc:0.707681
# [137]	train-auc:0.806480	eval-auc:0.707714
# [138]	train-auc:0.806901	eval-auc:0.707779
# [139]	train-auc:0.807098	eval-auc:0.707807
# [140]	train-auc:0.807310	eval-auc:0.707864
# [141]	train-auc:0.807617	eval-auc:0.707902
# [142]	train-auc:0.808050	eval-auc:0.707908
# [143]	train-auc:0.808497	eval-auc:0.707997
# [144]	train-auc:0.808798	eval-auc:0.708013
# [145]	train-auc:0.809049	eval-auc:0.708051
# [146]	train-auc:0.809246	eval-auc:0.708141
# [147]	train-auc:0.809333	eval-auc:0.708143
# [148]	train-auc:0.809570	eval-auc:0.708139
# [149]	train-auc:0.809856	eval-auc:0.708125
# [150]	train-auc:0.810019	eval-auc:0.708182
# [151]	train-auc:0.810245	eval-auc:0.708252
# [152]	train-auc:0.810377	eval-auc:0.708258
# [153]	train-auc:0.810720	eval-auc:0.708259
# [154]	train-auc:0.810973	eval-auc:0.708312
# [155]	train-auc:0.811212	eval-auc:0.708374
# [156]	train-auc:0.811521	eval-auc:0.708442
# [157]	train-auc:0.811820	eval-auc:0.708453
# [158]	train-auc:0.812016	eval-auc:0.708467
# [159]	train-auc:0.812208	eval-auc:0.708481
# [160]	train-auc:0.812450	eval-auc:0.708478
# [161]	train-auc:0.812644	eval-auc:0.708539
# [162]	train-auc:0.812873	eval-auc:0.708578
# [163]	train-auc:0.813023	eval-auc:0.708564
# [164]	train-auc:0.813140	eval-auc:0.708557
# [165]	train-auc:0.813411	eval-auc:0.708603
# [166]	train-auc:0.813739	eval-auc:0.708649
# [167]	train-auc:0.814096	eval-auc:0.708702
# [168]	train-auc:0.814154	eval-auc:0.708738
# [169]	train-auc:0.814365	eval-auc:0.708775
# [170]	train-auc:0.814520	eval-auc:0.708785
# [171]	train-auc:0.814628	eval-auc:0.708782
# [172]	train-auc:0.814903	eval-auc:0.708821
# [173]	train-auc:0.815250	eval-auc:0.708871
# [174]	train-auc:0.815381	eval-auc:0.708866
# [175]	train-auc:0.815617	eval-auc:0.708884
# [176]	train-auc:0.815940	eval-auc:0.708880
# [177]	train-auc:0.816119	eval-auc:0.708895
# [178]	train-auc:0.816362	eval-auc:0.708893
# [179]	train-auc:0.816632	eval-auc:0.708903
# [180]	train-auc:0.817007	eval-auc:0.708955
# [181]	train-auc:0.817133	eval-auc:0.708962
# [182]	train-auc:0.817370	eval-auc:0.709029
# [183]	train-auc:0.817651	eval-auc:0.709151
# [184]	train-auc:0.817879	eval-auc:0.709199
# [185]	train-auc:0.818128	eval-auc:0.709267
# [186]	train-auc:0.818424	eval-auc:0.709257
# [187]	train-auc:0.818600	eval-auc:0.709281
# [188]	train-auc:0.818735	eval-auc:0.709323
# [189]	train-auc:0.819047	eval-auc:0.709320
# [190]	train-auc:0.819136	eval-auc:0.709347
# [191]	train-auc:0.819430	eval-auc:0.709304
# [192]	train-auc:0.819670	eval-auc:0.709351
# [193]	train-auc:0.819913	eval-auc:0.709334
# [194]	train-auc:0.820256	eval-auc:0.709379
# [195]	train-auc:0.820382	eval-auc:0.709416
# [196]	train-auc:0.820534	eval-auc:0.709428
# [197]	train-auc:0.820683	eval-auc:0.709428
# [198]	train-auc:0.821023	eval-auc:0.709446
# [199]	train-auc:0.821086	eval-auc:0.709462
# [200]	train-auc:0.821231	eval-auc:0.709495
# [201]	train-auc:0.821355	eval-auc:0.709511
# [202]	train-auc:0.821456	eval-auc:0.709518
# [203]	train-auc:0.821651	eval-auc:0.709523
# [204]	train-auc:0.821705	eval-auc:0.709533
# [205]	train-auc:0.821863	eval-auc:0.709539
# [206]	train-auc:0.821984	eval-auc:0.709555
# [207]	train-auc:0.821989	eval-auc:0.709548
# [208]	train-auc:0.822132	eval-auc:0.709549
# [209]	train-auc:0.822337	eval-auc:0.709672
# [210]	train-auc:0.822506	eval-auc:0.709707
# [211]	train-auc:0.822685	eval-auc:0.709716
# [212]	train-auc:0.822991	eval-auc:0.709756
# [213]	train-auc:0.823292	eval-auc:0.709751
# [214]	train-auc:0.823493	eval-auc:0.709817
# [215]	train-auc:0.823738	eval-auc:0.709816
# [216]	train-auc:0.823864	eval-auc:0.709836
# [217]	train-auc:0.823949	eval-auc:0.709840
# [218]	train-auc:0.824016	eval-auc:0.709843
# [219]	train-auc:0.824146	eval-auc:0.709842
# [220]	train-auc:0.824390	eval-auc:0.709853
# [221]	train-auc:0.824497	eval-auc:0.709846
# [222]	train-auc:0.824593	eval-auc:0.709865
# [223]	train-auc:0.824668	eval-auc:0.709882
# [224]	train-auc:0.824739	eval-auc:0.709868
# [225]	train-auc:0.824878	eval-auc:0.709874
# [226]	train-auc:0.825106	eval-auc:0.709942
# [227]	train-auc:0.825150	eval-auc:0.709936
# [228]	train-auc:0.825216	eval-auc:0.709944
# [229]	train-auc:0.825393	eval-auc:0.709967
# [230]	train-auc:0.825540	eval-auc:0.710010
# [231]	train-auc:0.825628	eval-auc:0.710018
# [232]	train-auc:0.825877	eval-auc:0.710070
# [233]	train-auc:0.825927	eval-auc:0.710084
# [234]	train-auc:0.826097	eval-auc:0.710142
# [235]	train-auc:0.826324	eval-auc:0.710156
# [236]	train-auc:0.826614	eval-auc:0.710225
# [237]	train-auc:0.826733	eval-auc:0.710227
# [238]	train-auc:0.826867	eval-auc:0.710242
# [239]	train-auc:0.827054	eval-auc:0.710259
# [240]	train-auc:0.827160	eval-auc:0.710299
# [241]	train-auc:0.827334	eval-auc:0.710335
# [242]	train-auc:0.827533	eval-auc:0.710316
# [243]	train-auc:0.827651	eval-auc:0.710340
# [244]	train-auc:0.827896	eval-auc:0.710343
# [245]	train-auc:0.828140	eval-auc:0.710320
# [246]	train-auc:0.828317	eval-auc:0.710325
# [247]	train-auc:0.828500	eval-auc:0.710327
# [248]	train-auc:0.828616	eval-auc:0.710374
# [249]	train-auc:0.828685	eval-auc:0.710396
# [250]	train-auc:0.828793	eval-auc:0.710413
# [251]	train-auc:0.828880	eval-auc:0.710432
# [252]	train-auc:0.829008	eval-auc:0.710438
# [253]	train-auc:0.829262	eval-auc:0.710535
# [254]	train-auc:0.829393	eval-auc:0.710516
# [255]	train-auc:0.829455	eval-auc:0.710510
# [256]	train-auc:0.829695	eval-auc:0.710510
# [257]	train-auc:0.829791	eval-auc:0.710510
# [258]	train-auc:0.829878	eval-auc:0.710527
# [259]	train-auc:0.829943	eval-auc:0.710533
# [260]	train-auc:0.830007	eval-auc:0.710537
# [261]	train-auc:0.830172	eval-auc:0.710594
# [262]	train-auc:0.830370	eval-auc:0.710598
# [263]	train-auc:0.830519	eval-auc:0.710614
# [264]	train-auc:0.830747	eval-auc:0.710631
# [265]	train-auc:0.830872	eval-auc:0.710627
# [266]	train-auc:0.831020	eval-auc:0.710656
# [267]	train-auc:0.831111	eval-auc:0.710656
# [268]	train-auc:0.831217	eval-auc:0.710674
# [269]	train-auc:0.831350	eval-auc:0.710682
# [270]	train-auc:0.831441	eval-auc:0.710690
# [271]	train-auc:0.831497	eval-auc:0.710676
# [272]	train-auc:0.831691	eval-auc:0.710681
# [273]	train-auc:0.831789	eval-auc:0.710696
# [274]	train-auc:0.832004	eval-auc:0.710734
# [275]	train-auc:0.832071	eval-auc:0.710773
# [276]	train-auc:0.832115	eval-auc:0.710775
# [277]	train-auc:0.832199	eval-auc:0.710795
# [278]	train-auc:0.832283	eval-auc:0.710811
# [279]	train-auc:0.832479	eval-auc:0.710803
# [280]	train-auc:0.832515	eval-auc:0.710811
# [281]	train-auc:0.832669	eval-auc:0.710863
# [282]	train-auc:0.832736	eval-auc:0.710890
# [283]	train-auc:0.832857	eval-auc:0.710891
# [284]	train-auc:0.833072	eval-auc:0.710914
# [285]	train-auc:0.833160	eval-auc:0.710935
# [286]	train-auc:0.833257	eval-auc:0.710960
# [287]	train-auc:0.833310	eval-auc:0.710969
# [288]	train-auc:0.833417	eval-auc:0.710958
# [289]	train-auc:0.833514	eval-auc:0.710968
# [290]	train-auc:0.833542	eval-auc:0.710976
# [291]	train-auc:0.833569	eval-auc:0.710971
# [292]	train-auc:0.833669	eval-auc:0.710996
# [293]	train-auc:0.833760	eval-auc:0.711025
# [294]	train-auc:0.833864	eval-auc:0.711011
# [295]	train-auc:0.833932	eval-auc:0.711008
# [296]	train-auc:0.834114	eval-auc:0.711005
# [297]	train-auc:0.834193	eval-auc:0.711057
# [298]	train-auc:0.834318	eval-auc:0.711036
# [299]	train-auc:0.834413	eval-auc:0.711089
# [300]	train-auc:0.834554	eval-auc:0.711093
# [301]	train-auc:0.834623	eval-auc:0.711106
# [302]	train-auc:0.834705	eval-auc:0.711129
# [303]	train-auc:0.834835	eval-auc:0.711142
# [304]	train-auc:0.834862	eval-auc:0.711152
# [305]	train-auc:0.834861	eval-auc:0.711155
# [306]	train-auc:0.834953	eval-auc:0.711168
# [307]	train-auc:0.835060	eval-auc:0.711193
# [308]	train-auc:0.835201	eval-auc:0.711179
# [309]	train-auc:0.835297	eval-auc:0.711213
# [310]	train-auc:0.835360	eval-auc:0.711213
# [311]	train-auc:0.835445	eval-auc:0.711205
# [312]	train-auc:0.835468	eval-auc:0.711216
# [313]	train-auc:0.835637	eval-auc:0.711196
# [314]	train-auc:0.835800	eval-auc:0.711215
# [315]	train-auc:0.835846	eval-auc:0.711231
# [316]	train-auc:0.836002	eval-auc:0.711222
# [317]	train-auc:0.836063	eval-auc:0.711227
# [318]	train-auc:0.836090	eval-auc:0.711245
# [319]	train-auc:0.836104	eval-auc:0.711238
# [320]	train-auc:0.836165	eval-auc:0.711255
# [321]	train-auc:0.836262	eval-auc:0.711241
# [322]	train-auc:0.836365	eval-auc:0.711225
# [323]	train-auc:0.836487	eval-auc:0.711223
# [324]	train-auc:0.836566	eval-auc:0.711238
# [325]	train-auc:0.836705	eval-auc:0.711228
# [326]	train-auc:0.836830	eval-auc:0.711247
# [327]	train-auc:0.836874	eval-auc:0.711266
# [328]	train-auc:0.837031	eval-auc:0.711275
# [329]	train-auc:0.837156	eval-auc:0.711297
# [330]	train-auc:0.837256	eval-auc:0.711272
# [331]	train-auc:0.837362	eval-auc:0.711259
# [332]	train-auc:0.837373	eval-auc:0.711265
# [333]	train-auc:0.837527	eval-auc:0.711273
# [334]	train-auc:0.837683	eval-auc:0.711268
# [335]	train-auc:0.837713	eval-auc:0.711262
# [336]	train-auc:0.837848	eval-auc:0.711240
# [337]	train-auc:0.837906	eval-auc:0.711268
# [338]	train-auc:0.837984	eval-auc:0.711274
# [339]	train-auc:0.838079	eval-auc:0.711303
# [340]	train-auc:0.838153	eval-auc:0.711307
# [341]	train-auc:0.838220	eval-auc:0.711309
# [342]	train-auc:0.838320	eval-auc:0.711349
# [343]	train-auc:0.838385	eval-auc:0.711378
# [344]	train-auc:0.838433	eval-auc:0.711383
# [345]	train-auc:0.838495	eval-auc:0.711396
# [346]	train-auc:0.838553	eval-auc:0.711364
# [347]	train-auc:0.838686	eval-auc:0.711342
# [348]	train-auc:0.838759	eval-auc:0.711370
# [349]	train-auc:0.838858	eval-auc:0.711382
# [350]	train-auc:0.838989	eval-auc:0.711379
# [351]	train-auc:0.839087	eval-auc:0.711396
# [352]	train-auc:0.839153	eval-auc:0.711403
# [353]	train-auc:0.839312	eval-auc:0.711377
# [354]	train-auc:0.839390	eval-auc:0.711364
# [355]	train-auc:0.839407	eval-auc:0.711359
# [356]	train-auc:0.839554	eval-auc:0.711381
# [357]	train-auc:0.839663	eval-auc:0.711379
# [358]	train-auc:0.839702	eval-auc:0.711394
# [359]	train-auc:0.839835	eval-auc:0.711375
# [360]	train-auc:0.839924	eval-auc:0.711384
# [361]	train-auc:0.840089	eval-auc:0.711389
# [362]	train-auc:0.840211	eval-auc:0.711421
# [363]	train-auc:0.840224	eval-auc:0.711423
# [364]	train-auc:0.840254	eval-auc:0.711430
# [365]	train-auc:0.840297	eval-auc:0.711444
# [366]	train-auc:0.840428	eval-auc:0.711475
# [367]	train-auc:0.840545	eval-auc:0.711474
# [368]	train-auc:0.840626	eval-auc:0.711486
# [369]	train-auc:0.840669	eval-auc:0.711520
# [370]	train-auc:0.840847	eval-auc:0.711518
# [371]	train-auc:0.840907	eval-auc:0.711509
# [372]	train-auc:0.840986	eval-auc:0.711511
# [373]	train-auc:0.841026	eval-auc:0.711517
# [374]	train-auc:0.841097	eval-auc:0.711512
# [375]	train-auc:0.841202	eval-auc:0.711522
# [376]	train-auc:0.841329	eval-auc:0.711544
# [377]	train-auc:0.841396	eval-auc:0.711542
# [378]	train-auc:0.841404	eval-auc:0.711545
# [379]	train-auc:0.841448	eval-auc:0.711530
# [380]	train-auc:0.841550	eval-auc:0.711530
# [381]	train-auc:0.841697	eval-auc:0.711520
# [382]	train-auc:0.841776	eval-auc:0.711544
# [383]	train-auc:0.841946	eval-auc:0.711553
# [384]	train-auc:0.842088	eval-auc:0.711561
# [385]	train-auc:0.842134	eval-auc:0.711564
# [386]	train-auc:0.842237	eval-auc:0.711582
# [387]	train-auc:0.842326	eval-auc:0.711595
# [388]	train-auc:0.842458	eval-auc:0.711591
# [389]	train-auc:0.842576	eval-auc:0.711588
# [390]	train-auc:0.842655	eval-auc:0.711601
# [391]	train-auc:0.842792	eval-auc:0.711585
# [392]	train-auc:0.842858	eval-auc:0.711579
# [393]	train-auc:0.842906	eval-auc:0.711567
# [394]	train-auc:0.842959	eval-auc:0.711561
# [395]	train-auc:0.843004	eval-auc:0.711562
# [396]	train-auc:0.843136	eval-auc:0.711591
# [397]	train-auc:0.843240	eval-auc:0.711606
# [398]	train-auc:0.843334	eval-auc:0.711600
# [399]	train-auc:0.843349	eval-auc:0.711613
# [400]	train-auc:0.843445	eval-auc:0.711649
# [401]	train-auc:0.843477	eval-auc:0.711650
# [402]	train-auc:0.843586	eval-auc:0.711656
# [403]	train-auc:0.843608	eval-auc:0.711646
# [404]	train-auc:0.843635	eval-auc:0.711648
# [405]	train-auc:0.843754	eval-auc:0.711647
# [406]	train-auc:0.843811	eval-auc:0.711660
# [407]	train-auc:0.843834	eval-auc:0.711664
# [408]	train-auc:0.843861	eval-auc:0.711652
# [409]	train-auc:0.843959	eval-auc:0.711637
# [410]	train-auc:0.844081	eval-auc:0.711655
# [411]	train-auc:0.844174	eval-auc:0.711671
# [412]	train-auc:0.844305	eval-auc:0.711679
# [413]	train-auc:0.844388	eval-auc:0.711680
# [414]	train-auc:0.844398	eval-auc:0.711680
# [415]	train-auc:0.844489	eval-auc:0.711686
# [416]	train-auc:0.844577	eval-auc:0.711686
# [417]	train-auc:0.844625	eval-auc:0.711679
# [418]	train-auc:0.844696	eval-auc:0.711672
# [419]	train-auc:0.844777	eval-auc:0.711676
# [420]	train-auc:0.844889	eval-auc:0.711677
# [421]	train-auc:0.845054	eval-auc:0.711675
# [422]	train-auc:0.845121	eval-auc:0.711677
# [423]	train-auc:0.845165	eval-auc:0.711690
# [424]	train-auc:0.845215	eval-auc:0.711680
# [425]	train-auc:0.845283	eval-auc:0.711709
# [426]	train-auc:0.845364	eval-auc:0.711689
# [427]	train-auc:0.845415	eval-auc:0.711690
# [428]	train-auc:0.845599	eval-auc:0.711727
# [429]	train-auc:0.845800	eval-auc:0.711734
# [430]	train-auc:0.845847	eval-auc:0.711751
# [431]	train-auc:0.845876	eval-auc:0.711751
# [432]	train-auc:0.845977	eval-auc:0.711758
# [433]	train-auc:0.846096	eval-auc:0.711784
# [434]	train-auc:0.846167	eval-auc:0.711781
# [435]	train-auc:0.846178	eval-auc:0.711781
# [436]	train-auc:0.846250	eval-auc:0.711794
# [437]	train-auc:0.846299	eval-auc:0.711800
# [438]	train-auc:0.846385	eval-auc:0.711782
# [439]	train-auc:0.846455	eval-auc:0.711774
# [440]	train-auc:0.846531	eval-auc:0.711758
# [441]	train-auc:0.846609	eval-auc:0.711775
# [442]	train-auc:0.846793	eval-auc:0.711777
# [443]	train-auc:0.846855	eval-auc:0.711810
# [444]	train-auc:0.846912	eval-auc:0.711801
# [445]	train-auc:0.847012	eval-auc:0.711795
# [446]	train-auc:0.847093	eval-auc:0.711801
# [447]	train-auc:0.847122	eval-auc:0.711803
# [448]	train-auc:0.847137	eval-auc:0.711797
# [449]	train-auc:0.847206	eval-auc:0.711802
# [450]	train-auc:0.847231	eval-auc:0.711798
# [451]	train-auc:0.847319	eval-auc:0.711790
# [452]	train-auc:0.847367	eval-auc:0.711796
# [453]	train-auc:0.847468	eval-auc:0.711781
# [454]	train-auc:0.847604	eval-auc:0.711756
# [455]	train-auc:0.847725	eval-auc:0.711753
# [456]	train-auc:0.847782	eval-auc:0.711794
# [457]	train-auc:0.847889	eval-auc:0.711803
# [458]	train-auc:0.847893	eval-auc:0.711799
# [459]	train-auc:0.848055	eval-auc:0.711791
# [460]	train-auc:0.848077	eval-auc:0.711800
# [461]	train-auc:0.848149	eval-auc:0.711818
# [462]	train-auc:0.848215	eval-auc:0.711829
# [463]	train-auc:0.848228	eval-auc:0.711824
# [464]	train-auc:0.848315	eval-auc:0.711822
# [465]	train-auc:0.848359	eval-auc:0.711810
# [466]	train-auc:0.848423	eval-auc:0.711819
# [467]	train-auc:0.848511	eval-auc:0.711833
# [468]	train-auc:0.848562	eval-auc:0.711848
# [469]	train-auc:0.848633	eval-auc:0.711858
# [470]	train-auc:0.848660	eval-auc:0.711853
# [471]	train-auc:0.848734	eval-auc:0.711865
# [472]	train-auc:0.848897	eval-auc:0.711870
# [473]	train-auc:0.848974	eval-auc:0.711858
# [474]	train-auc:0.849142	eval-auc:0.711824
# [475]	train-auc:0.849158	eval-auc:0.711820
# [476]	train-auc:0.849180	eval-auc:0.711814
# [477]	train-auc:0.849212	eval-auc:0.711819
# [478]	train-auc:0.849330	eval-auc:0.711811
# [479]	train-auc:0.849440	eval-auc:0.711799
# [480]	train-auc:0.849477	eval-auc:0.711792
# [481]	train-auc:0.849655	eval-auc:0.711804
# [482]	train-auc:0.849724	eval-auc:0.711815
# [483]	train-auc:0.849874	eval-auc:0.711801
# [484]	train-auc:0.850012	eval-auc:0.711806
# [485]	train-auc:0.850168	eval-auc:0.711814
# [486]	train-auc:0.850279	eval-auc:0.711829
# [487]	train-auc:0.850403	eval-auc:0.711851
# [488]	train-auc:0.850410	eval-auc:0.711849
# [489]	train-auc:0.850439	eval-auc:0.711848
# [490]	train-auc:0.850483	eval-auc:0.711853
# [491]	train-auc:0.850537	eval-auc:0.711861
# [492]	train-auc:0.850606	eval-auc:0.711840
# [493]	train-auc:0.850643	eval-auc:0.711835
# [494]	train-auc:0.850700	eval-auc:0.711835
# [495]	train-auc:0.850841	eval-auc:0.711860
# [496]	train-auc:0.850935	eval-auc:0.711855
# [497]	train-auc:0.851034	eval-auc:0.711860
# [498]	train-auc:0.851123	eval-auc:0.711887
# [499]	train-auc:0.851162	eval-auc:0.711886
# [500]	train-auc:0.851357	eval-auc:0.711906
# [501]	train-auc:0.851422	eval-auc:0.711915
# [502]	train-auc:0.851486	eval-auc:0.711899
# [503]	train-auc:0.851561	eval-auc:0.711910
# [504]	train-auc:0.851619	eval-auc:0.711917
# [505]	train-auc:0.851702	eval-auc:0.711938
# [506]	train-auc:0.851802	eval-auc:0.711936
# [507]	train-auc:0.851891	eval-auc:0.711927
# [508]	train-auc:0.851990	eval-auc:0.711917
# [509]	train-auc:0.852086	eval-auc:0.711920
# [510]	train-auc:0.852188	eval-auc:0.711907
# [511]	train-auc:0.852274	eval-auc:0.711918
# [512]	train-auc:0.852346	eval-auc:0.711920
# [513]	train-auc:0.852456	eval-auc:0.711941
# [514]	train-auc:0.852569	eval-auc:0.711932
# [515]	train-auc:0.852630	eval-auc:0.711922
# [516]	train-auc:0.852660	eval-auc:0.711919
# [517]	train-auc:0.852817	eval-auc:0.711911
# [518]	train-auc:0.852869	eval-auc:0.711916
# [519]	train-auc:0.852894	eval-auc:0.711906
# [520]	train-auc:0.852941	eval-auc:0.711917
# [521]	train-auc:0.853010	eval-auc:0.711912
# [522]	train-auc:0.853081	eval-auc:0.711912
# [523]	train-auc:0.853157	eval-auc:0.711901
# [524]	train-auc:0.853277	eval-auc:0.711895
# [525]	train-auc:0.853328	eval-auc:0.711896
# [526]	train-auc:0.853367	eval-auc:0.711912
# [527]	train-auc:0.853483	eval-auc:0.711895
# [528]	train-auc:0.853595	eval-auc:0.711888
# [529]	train-auc:0.853678	eval-auc:0.711911
# [530]	train-auc:0.853721	eval-auc:0.711920
# [531]	train-auc:0.853739	eval-auc:0.711919
# [532]	train-auc:0.853742	eval-auc:0.711914
# [533]	train-auc:0.853884	eval-auc:0.711907
# [534]	train-auc:0.853926	eval-auc:0.711921
# [535]	train-auc:0.853997	eval-auc:0.711921
# [536]	train-auc:0.854041	eval-auc:0.711920
# [537]	train-auc:0.854169	eval-auc:0.711924
# [538]	train-auc:0.854205	eval-auc:0.711918
# [539]	train-auc:0.854267	eval-auc:0.711919
# [540]	train-auc:0.854335	eval-auc:0.711929
# [541]	train-auc:0.854340	eval-auc:0.711932
# [542]	train-auc:0.854396	eval-auc:0.711944
# [543]	train-auc:0.854441	eval-auc:0.711934
# [544]	train-auc:0.854471	eval-auc:0.711947
# [545]	train-auc:0.854496	eval-auc:0.711950
# [546]	train-auc:0.854519	eval-auc:0.711949
# [547]	train-auc:0.854683	eval-auc:0.711947
# [548]	train-auc:0.854737	eval-auc:0.711936
# [549]	train-auc:0.854817	eval-auc:0.711927
# [550]	train-auc:0.854866	eval-auc:0.711931
# [551]	train-auc:0.854964	eval-auc:0.711951
# [552]	train-auc:0.855032	eval-auc:0.711954
# [553]	train-auc:0.855111	eval-auc:0.711968
# [554]	train-auc:0.855143	eval-auc:0.711965
# [555]	train-auc:0.855185	eval-auc:0.711975
# [556]	train-auc:0.855279	eval-auc:0.711968
# [557]	train-auc:0.855290	eval-auc:0.711969
# [558]	train-auc:0.855339	eval-auc:0.711966
# [559]	train-auc:0.855402	eval-auc:0.711985
# [560]	train-auc:0.855447	eval-auc:0.711993
# [561]	train-auc:0.855576	eval-auc:0.711995
# [562]	train-auc:0.855629	eval-auc:0.711991
# [563]	train-auc:0.855703	eval-auc:0.711993
# [564]	train-auc:0.855737	eval-auc:0.711995
# [565]	train-auc:0.855818	eval-auc:0.712027
# [566]	train-auc:0.855982	eval-auc:0.712032
# [567]	train-auc:0.856073	eval-auc:0.712020
# [568]	train-auc:0.856135	eval-auc:0.712008
# [569]	train-auc:0.856229	eval-auc:0.711997
# [570]	train-auc:0.856288	eval-auc:0.711988
# [571]	train-auc:0.856315	eval-auc:0.711985
# [572]	train-auc:0.856344	eval-auc:0.711983
# [573]	train-auc:0.856402	eval-auc:0.711970
# [574]	train-auc:0.856474	eval-auc:0.711987
# [575]	train-auc:0.856631	eval-auc:0.711989
# [576]	train-auc:0.856732	eval-auc:0.712004
# [577]	train-auc:0.856831	eval-auc:0.711999
# [578]	train-auc:0.856877	eval-auc:0.712017
# [579]	train-auc:0.856918	eval-auc:0.712018
# [580]	train-auc:0.857095	eval-auc:0.712008
# [581]	train-auc:0.857136	eval-auc:0.712007
# [582]	train-auc:0.857215	eval-auc:0.712021
# [583]	train-auc:0.857243	eval-auc:0.712020
# [584]	train-auc:0.857310	eval-auc:0.712022
# [585]	train-auc:0.857353	eval-auc:0.712037
# [586]	train-auc:0.857380	eval-auc:0.712052
# [587]	train-auc:0.857413	eval-auc:0.712061
# [588]	train-auc:0.857497	eval-auc:0.712047
# [589]	train-auc:0.857583	eval-auc:0.712057
# loading data end, start to boost trees

# %% [markdown]
# ## on df1

# %%
# Columns selected by RFECV
columns1 = ['APP_NB', 'APP_NB_PAYS', 'APP_NB_TYPE', 'COUNTRY', 'FIRST_CLASSE', 'FISRT_APP_COUNTRY', 
            'FISRT_APP_TYPE', 'FISRT_INV_COUNTRY', 'FISRT_INV_TYPE', 'IDX_ORIGIN', 'IDX_RADIC', 'INV_NB',
            'INV_NB_PAYS', 'INV_NB_TYPE', 'LANGUAGE_OF_FILLING', 'MAIN_IPC', 'NB_BACKWARD', 'NB_BACKWARD_AUTRE',
            'NB_BACKWARD_NPL', 'NB_BACKWARD_PL', 'NB_BACKWARD_XY', 'NB_CLASSES', 'NB_FIELDS', 'NB_ROOT_CLASSES',
            'NB_SECTORS', 'SOURCE_BEGIN_MONTH', 'SOURCE_IDX_RAD', 'TECHNOLOGIE_FIELD', 'TECHNOLOGIE_SECTOR',
            'cited_age_max', 'cited_age_mean', 'cited_age_median', 'cited_age_min', 'cited_age_std', 'cited_n',
            'oecd_NB_BACKWARD_NPL', 'oecd_NB_BACKWARD_PL', 'oecd_NB_ROOT_CLASSES', 'pct_NB_IPC', 'pct_NB_IPC_LY',
            'filing-begin', 'pub-filing', 'pub_year', 'VARIABLE_CIBLE']

df_train1, df_test1 = train_test_split(df1_train[columns1], test_size=0.2, random_state=42)

columns1.remove('VARIABLE_CIBLE')

test_size = len(df_test1)
train_size = len(df_train1)
# rescale weight to make it same as test set
weight = np.ones(train_size) * float(test_size) / float(train_size)

# computing weights to balance the repartition of 'VARIABLE_CIBLE'values
sum_wpos = sum( weight[i] for i in range(train_size) if df_train1['VARIABLE_CIBLE'].iloc[i] == 1.0  )
sum_wneg = sum( weight[i] for i in range(train_size) if df_train1['VARIABLE_CIBLE'].iloc[i] == 0.0  )

# construct xgboost.DMatrix from numpy array, treat -999.0 as missing value
dtrain1 = xgb.DMatrix( df_train1[columns1].values, label=df_train1['VARIABLE_CIBLE'].values, weight=weight )
dtest1 = xgb.DMatrix( df_test1[columns1].values, label=df_test1['VARIABLE_CIBLE'].values)

# %%
# parameters optained with hyperopt
param = {'colsample_bytree': 0.5, 'min_child_weight': 4.0, 'subsample': 0.8,
         'eta': 0.025, 'max_depth': 9.0, 'gamma': 0.7000000000000001,
         'objective': 'binary:logistic',
         'nthread': 6, 'scale_pos_weight': sum_wneg/sum_wpos, 'eval_metric': 'auc', 'silent': 0}



plst = list(param.items())

evallist  = [(dtrain1,'train'), (dtest1,'eval')]



num_round = 664
print ('loading data end, start to boost trees')
bst1 = xgb.train( plst, dtrain1, num_round, evallist)#, early_stopping_rounds=50 );
# save out model
bst1.save_model('df1_xgboost_optimized.model')
# Out:
# [0]	train-auc:0.682331	eval-auc:0.650454
# [1]	train-auc:0.702271	eval-auc:0.665190
# [2]	train-auc:0.708856	eval-auc:0.672176
# [3]	train-auc:0.710931	eval-auc:0.673586
# [4]	train-auc:0.714125	eval-auc:0.676053
# [5]	train-auc:0.715907	eval-auc:0.676413
# [6]	train-auc:0.719519	eval-auc:0.677203
# [7]	train-auc:0.722659	eval-auc:0.678032
# [8]	train-auc:0.724661	eval-auc:0.679861
# [9]	train-auc:0.725724	eval-auc:0.680706
# [10]	train-auc:0.726044	eval-auc:0.680456
# [11]	train-auc:0.728047	eval-auc:0.681770
# [12]	train-auc:0.730716	eval-auc:0.683725
# [13]	train-auc:0.732351	eval-auc:0.684556
# [14]	train-auc:0.733652	eval-auc:0.685823
# [15]	train-auc:0.733548	eval-auc:0.685572
# [16]	train-auc:0.734400	eval-auc:0.686349
# [17]	train-auc:0.734781	eval-auc:0.686108
# [18]	train-auc:0.735684	eval-auc:0.686366
# [19]	train-auc:0.736426	eval-auc:0.686411
# [20]	train-auc:0.737105	eval-auc:0.686971
# [21]	train-auc:0.737413	eval-auc:0.686790
# [22]	train-auc:0.738875	eval-auc:0.687582
# [23]	train-auc:0.739745	eval-auc:0.687882
# [24]	train-auc:0.739882	eval-auc:0.687551
# [25]	train-auc:0.740561	eval-auc:0.687838
# [26]	train-auc:0.741113	eval-auc:0.687968
# [27]	train-auc:0.741310	eval-auc:0.687640
# [28]	train-auc:0.741721	eval-auc:0.687881
# [29]	train-auc:0.742692	eval-auc:0.688317
# [30]	train-auc:0.743659	eval-auc:0.688871
# [31]	train-auc:0.743641	eval-auc:0.688940
# [32]	train-auc:0.743948	eval-auc:0.689371
# [33]	train-auc:0.744140	eval-auc:0.689087
# [34]	train-auc:0.744404	eval-auc:0.689553
# [35]	train-auc:0.744725	eval-auc:0.689539
# [36]	train-auc:0.744919	eval-auc:0.689577
# [37]	train-auc:0.745201	eval-auc:0.689743
# [38]	train-auc:0.745333	eval-auc:0.689735
# [39]	train-auc:0.746124	eval-auc:0.690268
# [40]	train-auc:0.746393	eval-auc:0.690350
# [41]	train-auc:0.746700	eval-auc:0.690732
# [42]	train-auc:0.746826	eval-auc:0.690647
# [43]	train-auc:0.747396	eval-auc:0.690838
# [44]	train-auc:0.747714	eval-auc:0.690803
# [45]	train-auc:0.748229	eval-auc:0.690818
# [46]	train-auc:0.748700	eval-auc:0.690916
# [47]	train-auc:0.749207	eval-auc:0.691026
# [48]	train-auc:0.749609	eval-auc:0.691002
# [49]	train-auc:0.750181	eval-auc:0.690939
# [50]	train-auc:0.750543	eval-auc:0.691049
# [51]	train-auc:0.750731	eval-auc:0.691274
# [52]	train-auc:0.751192	eval-auc:0.691320
# [53]	train-auc:0.751523	eval-auc:0.691603
# [54]	train-auc:0.751655	eval-auc:0.691576
# [55]	train-auc:0.752243	eval-auc:0.691945
# [56]	train-auc:0.752627	eval-auc:0.692181
# [57]	train-auc:0.753020	eval-auc:0.692095
# [58]	train-auc:0.753463	eval-auc:0.692127
# [59]	train-auc:0.753796	eval-auc:0.692283
# [60]	train-auc:0.754078	eval-auc:0.692241
# [61]	train-auc:0.754305	eval-auc:0.692252
# [62]	train-auc:0.754553	eval-auc:0.692241
# [63]	train-auc:0.755189	eval-auc:0.692496
# [64]	train-auc:0.755716	eval-auc:0.692619
# [65]	train-auc:0.756172	eval-auc:0.692803
# [66]	train-auc:0.756407	eval-auc:0.692839
# [67]	train-auc:0.756735	eval-auc:0.692841
# [68]	train-auc:0.757178	eval-auc:0.693015
# [69]	train-auc:0.757597	eval-auc:0.693323
# [70]	train-auc:0.757900	eval-auc:0.693301
# [71]	train-auc:0.758237	eval-auc:0.693340
# [72]	train-auc:0.758982	eval-auc:0.693840
# [73]	train-auc:0.759329	eval-auc:0.693959
# [74]	train-auc:0.759830	eval-auc:0.694083
# [75]	train-auc:0.760232	eval-auc:0.694078
# [76]	train-auc:0.760569	eval-auc:0.694159
# [77]	train-auc:0.760901	eval-auc:0.694250
# [78]	train-auc:0.761071	eval-auc:0.694305
# [79]	train-auc:0.761414	eval-auc:0.694453
# [80]	train-auc:0.762090	eval-auc:0.694517
# [81]	train-auc:0.762633	eval-auc:0.694653
# [82]	train-auc:0.763009	eval-auc:0.694829
# [83]	train-auc:0.763431	eval-auc:0.694879
# [84]	train-auc:0.763594	eval-auc:0.694870
# [85]	train-auc:0.763896	eval-auc:0.695015
# [86]	train-auc:0.764365	eval-auc:0.695100
# [87]	train-auc:0.764827	eval-auc:0.695205
# [88]	train-auc:0.765250	eval-auc:0.695387
# [89]	train-auc:0.765703	eval-auc:0.695511
# [90]	train-auc:0.766093	eval-auc:0.695629
# [91]	train-auc:0.766359	eval-auc:0.695634
# [92]	train-auc:0.766679	eval-auc:0.695651
# [93]	train-auc:0.767059	eval-auc:0.695830
# [94]	train-auc:0.767606	eval-auc:0.695893
# [95]	train-auc:0.767863	eval-auc:0.695937
# [96]	train-auc:0.768157	eval-auc:0.696017
# [97]	train-auc:0.768593	eval-auc:0.696146
# [98]	train-auc:0.768883	eval-auc:0.696315
# [99]	train-auc:0.769150	eval-auc:0.696447
# [100]	train-auc:0.769348	eval-auc:0.696551
# [101]	train-auc:0.769843	eval-auc:0.696523
# [102]	train-auc:0.770135	eval-auc:0.696541
# [103]	train-auc:0.770289	eval-auc:0.696530
# [104]	train-auc:0.770429	eval-auc:0.696453
# [105]	train-auc:0.770817	eval-auc:0.696445
# [106]	train-auc:0.770979	eval-auc:0.696563
# [107]	train-auc:0.771201	eval-auc:0.696620
# [108]	train-auc:0.771568	eval-auc:0.696586
# [109]	train-auc:0.771968	eval-auc:0.696855
# [110]	train-auc:0.772245	eval-auc:0.696841
# [111]	train-auc:0.772491	eval-auc:0.696828
# [112]	train-auc:0.772811	eval-auc:0.696790
# [113]	train-auc:0.773082	eval-auc:0.696736
# [114]	train-auc:0.773395	eval-auc:0.696774
# [115]	train-auc:0.773853	eval-auc:0.696817
# [116]	train-auc:0.774225	eval-auc:0.696898
# [117]	train-auc:0.774405	eval-auc:0.696951
# [118]	train-auc:0.774680	eval-auc:0.697005
# [119]	train-auc:0.775044	eval-auc:0.697019
# [120]	train-auc:0.775312	eval-auc:0.697081
# [121]	train-auc:0.775594	eval-auc:0.697137
# [122]	train-auc:0.775824	eval-auc:0.697194
# [123]	train-auc:0.776217	eval-auc:0.697280
# [124]	train-auc:0.776519	eval-auc:0.697269
# [125]	train-auc:0.776900	eval-auc:0.697357
# [126]	train-auc:0.777173	eval-auc:0.697323
# [127]	train-auc:0.777524	eval-auc:0.697353
# [128]	train-auc:0.777820	eval-auc:0.697451
# [129]	train-auc:0.778028	eval-auc:0.697489
# [130]	train-auc:0.778410	eval-auc:0.697606
# [131]	train-auc:0.778646	eval-auc:0.697640
# [132]	train-auc:0.778808	eval-auc:0.697711
# [133]	train-auc:0.779214	eval-auc:0.697713
# [134]	train-auc:0.779432	eval-auc:0.697809
# [135]	train-auc:0.779629	eval-auc:0.697788
# [136]	train-auc:0.779995	eval-auc:0.697911
# [137]	train-auc:0.780416	eval-auc:0.697979
# [138]	train-auc:0.780721	eval-auc:0.698017
# [139]	train-auc:0.781105	eval-auc:0.698024
# [140]	train-auc:0.781478	eval-auc:0.697986
# [141]	train-auc:0.781717	eval-auc:0.698073
# [142]	train-auc:0.781891	eval-auc:0.698061
# [143]	train-auc:0.782107	eval-auc:0.698059
# [144]	train-auc:0.782416	eval-auc:0.698063
# [145]	train-auc:0.782543	eval-auc:0.698110
# [146]	train-auc:0.782712	eval-auc:0.698078
# [147]	train-auc:0.782991	eval-auc:0.698129
# [148]	train-auc:0.783434	eval-auc:0.698453
# [149]	train-auc:0.783655	eval-auc:0.698474
# [150]	train-auc:0.784037	eval-auc:0.698404
# [151]	train-auc:0.784270	eval-auc:0.698421
# [152]	train-auc:0.784706	eval-auc:0.698537
# [153]	train-auc:0.784956	eval-auc:0.698594
# [154]	train-auc:0.785219	eval-auc:0.698671
# [155]	train-auc:0.785457	eval-auc:0.698733
# [156]	train-auc:0.785588	eval-auc:0.698757
# [157]	train-auc:0.785838	eval-auc:0.698783
# [158]	train-auc:0.786109	eval-auc:0.698798
# [159]	train-auc:0.786223	eval-auc:0.698801
# [160]	train-auc:0.786296	eval-auc:0.698798
# [161]	train-auc:0.786652	eval-auc:0.698898
# [162]	train-auc:0.786805	eval-auc:0.698934
# [163]	train-auc:0.787125	eval-auc:0.698982
# [164]	train-auc:0.787369	eval-auc:0.699138
# [165]	train-auc:0.787708	eval-auc:0.699168
# [166]	train-auc:0.787936	eval-auc:0.699180
# [167]	train-auc:0.788206	eval-auc:0.699162
# [168]	train-auc:0.788586	eval-auc:0.699147
# [169]	train-auc:0.788789	eval-auc:0.699164
# [170]	train-auc:0.789001	eval-auc:0.699205
# [171]	train-auc:0.789150	eval-auc:0.699211
# [172]	train-auc:0.789350	eval-auc:0.699252
# [173]	train-auc:0.789572	eval-auc:0.699309
# [174]	train-auc:0.789857	eval-auc:0.699393
# [175]	train-auc:0.790074	eval-auc:0.699436
# [176]	train-auc:0.790315	eval-auc:0.699403
# [177]	train-auc:0.790847	eval-auc:0.699453
# [178]	train-auc:0.791141	eval-auc:0.699529
# [179]	train-auc:0.791209	eval-auc:0.699567
# [180]	train-auc:0.791627	eval-auc:0.699666
# [181]	train-auc:0.791861	eval-auc:0.699708
# [182]	train-auc:0.792145	eval-auc:0.699656
# [183]	train-auc:0.792452	eval-auc:0.699658
# [184]	train-auc:0.792740	eval-auc:0.699631
# [185]	train-auc:0.792897	eval-auc:0.699634
# [186]	train-auc:0.793230	eval-auc:0.699635
# [187]	train-auc:0.793398	eval-auc:0.699636
# [188]	train-auc:0.793655	eval-auc:0.699745
# [189]	train-auc:0.793802	eval-auc:0.699742
# [190]	train-auc:0.793937	eval-auc:0.699716
# [191]	train-auc:0.794080	eval-auc:0.699750
# [192]	train-auc:0.794315	eval-auc:0.699780
# [193]	train-auc:0.794430	eval-auc:0.699819
# [194]	train-auc:0.794514	eval-auc:0.699830
# [195]	train-auc:0.794675	eval-auc:0.699853
# [196]	train-auc:0.794821	eval-auc:0.699850
# [197]	train-auc:0.795007	eval-auc:0.699862
# [198]	train-auc:0.795290	eval-auc:0.699897
# [199]	train-auc:0.795548	eval-auc:0.699942
# [200]	train-auc:0.795825	eval-auc:0.699916
# [201]	train-auc:0.795971	eval-auc:0.699881
# [202]	train-auc:0.796131	eval-auc:0.699889
# [203]	train-auc:0.796417	eval-auc:0.699957
# [204]	train-auc:0.796594	eval-auc:0.699928
# [205]	train-auc:0.796732	eval-auc:0.699985
# [206]	train-auc:0.796888	eval-auc:0.700012
# [207]	train-auc:0.797078	eval-auc:0.700020
# [208]	train-auc:0.797257	eval-auc:0.700000
# [209]	train-auc:0.797433	eval-auc:0.700041
# [210]	train-auc:0.797585	eval-auc:0.699994
# [211]	train-auc:0.797753	eval-auc:0.699964
# [212]	train-auc:0.797926	eval-auc:0.699996
# [213]	train-auc:0.798067	eval-auc:0.700051
# [214]	train-auc:0.798266	eval-auc:0.700017
# [215]	train-auc:0.798699	eval-auc:0.700030
# [216]	train-auc:0.799013	eval-auc:0.700046
# [217]	train-auc:0.799310	eval-auc:0.700090
# [218]	train-auc:0.799507	eval-auc:0.700061
# [219]	train-auc:0.799646	eval-auc:0.700036
# [220]	train-auc:0.799864	eval-auc:0.700017
# [221]	train-auc:0.800136	eval-auc:0.700060
# [222]	train-auc:0.800340	eval-auc:0.700094
# [223]	train-auc:0.800560	eval-auc:0.700128
# [224]	train-auc:0.800829	eval-auc:0.700227
# [225]	train-auc:0.800952	eval-auc:0.700205
# [226]	train-auc:0.801120	eval-auc:0.700220
# [227]	train-auc:0.801248	eval-auc:0.700241
# [228]	train-auc:0.801383	eval-auc:0.700268
# [229]	train-auc:0.801582	eval-auc:0.700264
# [230]	train-auc:0.801689	eval-auc:0.700223
# [231]	train-auc:0.801837	eval-auc:0.700221
# [232]	train-auc:0.802158	eval-auc:0.700218
# [233]	train-auc:0.802413	eval-auc:0.700215
# [234]	train-auc:0.802600	eval-auc:0.700211
# [235]	train-auc:0.802788	eval-auc:0.700236
# [236]	train-auc:0.803005	eval-auc:0.700205
# [237]	train-auc:0.803291	eval-auc:0.700219
# [238]	train-auc:0.803521	eval-auc:0.700331
# [239]	train-auc:0.803783	eval-auc:0.700368
# [240]	train-auc:0.804030	eval-auc:0.700378
# [241]	train-auc:0.804205	eval-auc:0.700391
# [242]	train-auc:0.804248	eval-auc:0.700390
# [243]	train-auc:0.804434	eval-auc:0.700451
# [244]	train-auc:0.804722	eval-auc:0.700530
# [245]	train-auc:0.804817	eval-auc:0.700520
# [246]	train-auc:0.805088	eval-auc:0.700603
# [247]	train-auc:0.805371	eval-auc:0.700614
# [248]	train-auc:0.805624	eval-auc:0.700628
# [249]	train-auc:0.805817	eval-auc:0.700664
# [250]	train-auc:0.805929	eval-auc:0.700673
# [251]	train-auc:0.806116	eval-auc:0.700710
# [252]	train-auc:0.806334	eval-auc:0.700774
# [253]	train-auc:0.806390	eval-auc:0.700763
# [254]	train-auc:0.806509	eval-auc:0.700733
# [255]	train-auc:0.806668	eval-auc:0.700731
# [256]	train-auc:0.806787	eval-auc:0.700729
# [257]	train-auc:0.806944	eval-auc:0.700753
# [258]	train-auc:0.807056	eval-auc:0.700773
# [259]	train-auc:0.807214	eval-auc:0.700821
# [260]	train-auc:0.807521	eval-auc:0.700795
# [261]	train-auc:0.807643	eval-auc:0.700786
# [262]	train-auc:0.807706	eval-auc:0.700813
# [263]	train-auc:0.807759	eval-auc:0.700795
# [264]	train-auc:0.807779	eval-auc:0.700776
# [265]	train-auc:0.808018	eval-auc:0.700836
# [266]	train-auc:0.808177	eval-auc:0.700841
# [267]	train-auc:0.808330	eval-auc:0.700839
# [268]	train-auc:0.808515	eval-auc:0.700839
# [269]	train-auc:0.808603	eval-auc:0.700862
# [270]	train-auc:0.808895	eval-auc:0.700875
# [271]	train-auc:0.809073	eval-auc:0.700874
# [272]	train-auc:0.809210	eval-auc:0.700914
# [273]	train-auc:0.809368	eval-auc:0.700930
# [274]	train-auc:0.809490	eval-auc:0.700982
# [275]	train-auc:0.809596	eval-auc:0.701043
# [276]	train-auc:0.809665	eval-auc:0.701051
# [277]	train-auc:0.809736	eval-auc:0.701100
# [278]	train-auc:0.809863	eval-auc:0.701023
# [279]	train-auc:0.810047	eval-auc:0.701020
# [280]	train-auc:0.810124	eval-auc:0.701026
# [281]	train-auc:0.810203	eval-auc:0.701079
# [282]	train-auc:0.810424	eval-auc:0.701115
# [283]	train-auc:0.810462	eval-auc:0.701088
# [284]	train-auc:0.810554	eval-auc:0.701076
# [285]	train-auc:0.810690	eval-auc:0.701088
# [286]	train-auc:0.810677	eval-auc:0.701078
# [287]	train-auc:0.810837	eval-auc:0.701078
# [288]	train-auc:0.810981	eval-auc:0.701020
# [289]	train-auc:0.811174	eval-auc:0.701020
# [290]	train-auc:0.811489	eval-auc:0.701078
# [291]	train-auc:0.811624	eval-auc:0.701072
# [292]	train-auc:0.811663	eval-auc:0.701062
# [293]	train-auc:0.811719	eval-auc:0.701061
# [294]	train-auc:0.811797	eval-auc:0.701056
# [295]	train-auc:0.811964	eval-auc:0.701083
# [296]	train-auc:0.812105	eval-auc:0.701098
# [297]	train-auc:0.812258	eval-auc:0.701128
# [298]	train-auc:0.812338	eval-auc:0.701121
# [299]	train-auc:0.812453	eval-auc:0.701112
# [300]	train-auc:0.812671	eval-auc:0.701134
# [301]	train-auc:0.812819	eval-auc:0.701127
# [302]	train-auc:0.812961	eval-auc:0.701129
# [303]	train-auc:0.813035	eval-auc:0.701108
# [304]	train-auc:0.813099	eval-auc:0.701122
# [305]	train-auc:0.813332	eval-auc:0.701146
# [306]	train-auc:0.813393	eval-auc:0.701154
# [307]	train-auc:0.813479	eval-auc:0.701208
# [308]	train-auc:0.813577	eval-auc:0.701210
# [309]	train-auc:0.813764	eval-auc:0.701177
# [310]	train-auc:0.813985	eval-auc:0.701128
# [311]	train-auc:0.814083	eval-auc:0.701110
# [312]	train-auc:0.814152	eval-auc:0.701092
# [313]	train-auc:0.814324	eval-auc:0.701095
# [314]	train-auc:0.814450	eval-auc:0.701081
# [315]	train-auc:0.814683	eval-auc:0.701070
# [316]	train-auc:0.814878	eval-auc:0.701086
# [317]	train-auc:0.815361	eval-auc:0.701096
# [318]	train-auc:0.815590	eval-auc:0.701084
# [319]	train-auc:0.815785	eval-auc:0.701133
# [320]	train-auc:0.815974	eval-auc:0.701148
# [321]	train-auc:0.816097	eval-auc:0.701127
# [322]	train-auc:0.816175	eval-auc:0.701154
# [323]	train-auc:0.816393	eval-auc:0.701178
# [324]	train-auc:0.816580	eval-auc:0.701135
# [325]	train-auc:0.816688	eval-auc:0.701143
# [326]	train-auc:0.816797	eval-auc:0.701119
# [327]	train-auc:0.816928	eval-auc:0.701117
# [328]	train-auc:0.816994	eval-auc:0.701115
# [329]	train-auc:0.817181	eval-auc:0.701149
# [330]	train-auc:0.817263	eval-auc:0.701106
# [331]	train-auc:0.817429	eval-auc:0.701065
# [332]	train-auc:0.817489	eval-auc:0.701079
# [333]	train-auc:0.817671	eval-auc:0.701057
# [334]	train-auc:0.817788	eval-auc:0.701074
# [335]	train-auc:0.817819	eval-auc:0.701046
# [336]	train-auc:0.817925	eval-auc:0.701054
# [337]	train-auc:0.818170	eval-auc:0.701134
# [338]	train-auc:0.818371	eval-auc:0.701238
# [339]	train-auc:0.818423	eval-auc:0.701224
# [340]	train-auc:0.818468	eval-auc:0.701209
# [341]	train-auc:0.818570	eval-auc:0.701189
# [342]	train-auc:0.818634	eval-auc:0.701193
# [343]	train-auc:0.818838	eval-auc:0.701159
# [344]	train-auc:0.819071	eval-auc:0.701182
# [345]	train-auc:0.819185	eval-auc:0.701174
# [346]	train-auc:0.819322	eval-auc:0.701192
# [347]	train-auc:0.819384	eval-auc:0.701175
# [348]	train-auc:0.819608	eval-auc:0.701164
# [349]	train-auc:0.819739	eval-auc:0.701158
# [350]	train-auc:0.819926	eval-auc:0.701186
# [351]	train-auc:0.820043	eval-auc:0.701161
# [352]	train-auc:0.820198	eval-auc:0.701151
# [353]	train-auc:0.820304	eval-auc:0.701155
# [354]	train-auc:0.820360	eval-auc:0.701137
# [355]	train-auc:0.820458	eval-auc:0.701150
# [356]	train-auc:0.820546	eval-auc:0.701136
# [357]	train-auc:0.820659	eval-auc:0.701130
# [358]	train-auc:0.820700	eval-auc:0.701127
# [359]	train-auc:0.820761	eval-auc:0.701124
# [360]	train-auc:0.820787	eval-auc:0.701116
# [361]	train-auc:0.821051	eval-auc:0.701144
# [362]	train-auc:0.821289	eval-auc:0.701145
# [363]	train-auc:0.821388	eval-auc:0.701153
# [364]	train-auc:0.821579	eval-auc:0.701171
# [365]	train-auc:0.821633	eval-auc:0.701180
# [366]	train-auc:0.821668	eval-auc:0.701176
# [367]	train-auc:0.821785	eval-auc:0.701153
# [368]	train-auc:0.822078	eval-auc:0.701087
# [369]	train-auc:0.822148	eval-auc:0.701111
# [370]	train-auc:0.822316	eval-auc:0.701067
# [371]	train-auc:0.822378	eval-auc:0.701063
# [372]	train-auc:0.822480	eval-auc:0.701084
# [373]	train-auc:0.822527	eval-auc:0.701073
# [374]	train-auc:0.822561	eval-auc:0.701075
# [375]	train-auc:0.822734	eval-auc:0.701044
# [376]	train-auc:0.822849	eval-auc:0.701062
# [377]	train-auc:0.822930	eval-auc:0.701077
# [378]	train-auc:0.823039	eval-auc:0.701065
# [379]	train-auc:0.823112	eval-auc:0.701068
# [380]	train-auc:0.823163	eval-auc:0.701049
# [381]	train-auc:0.823302	eval-auc:0.701076
# [382]	train-auc:0.823409	eval-auc:0.701075
# [383]	train-auc:0.823535	eval-auc:0.701100
# [384]	train-auc:0.823704	eval-auc:0.701119
# [385]	train-auc:0.823814	eval-auc:0.701142
# [386]	train-auc:0.823991	eval-auc:0.701135
# [387]	train-auc:0.824046	eval-auc:0.701118
# [388]	train-auc:0.824202	eval-auc:0.701096
# [389]	train-auc:0.824267	eval-auc:0.701099
# [390]	train-auc:0.824345	eval-auc:0.701085
# [391]	train-auc:0.824592	eval-auc:0.701159
# [392]	train-auc:0.824746	eval-auc:0.701186
# [393]	train-auc:0.824927	eval-auc:0.701190
# [394]	train-auc:0.825008	eval-auc:0.701206
# [395]	train-auc:0.825125	eval-auc:0.701218
# [396]	train-auc:0.825228	eval-auc:0.701248
# [397]	train-auc:0.825305	eval-auc:0.701266
# [398]	train-auc:0.825327	eval-auc:0.701271
# [399]	train-auc:0.825353	eval-auc:0.701265
# [400]	train-auc:0.825487	eval-auc:0.701297
# [401]	train-auc:0.825540	eval-auc:0.701278
# [402]	train-auc:0.825849	eval-auc:0.701217
# [403]	train-auc:0.826051	eval-auc:0.701253
# [404]	train-auc:0.826172	eval-auc:0.701238
# [405]	train-auc:0.826503	eval-auc:0.701208
# [406]	train-auc:0.826649	eval-auc:0.701203
# [407]	train-auc:0.826719	eval-auc:0.701172
# [408]	train-auc:0.827007	eval-auc:0.701177
# [409]	train-auc:0.827076	eval-auc:0.701164
# [410]	train-auc:0.827080	eval-auc:0.701185
# [411]	train-auc:0.827166	eval-auc:0.701178
# [412]	train-auc:0.827217	eval-auc:0.701177
# [413]	train-auc:0.827411	eval-auc:0.701194
# [414]	train-auc:0.827430	eval-auc:0.701174
# [415]	train-auc:0.827642	eval-auc:0.701180
# [416]	train-auc:0.827696	eval-auc:0.701177
# [417]	train-auc:0.827763	eval-auc:0.701195
# [418]	train-auc:0.827975	eval-auc:0.701239
# [419]	train-auc:0.828020	eval-auc:0.701267
# [420]	train-auc:0.828236	eval-auc:0.701229
# [421]	train-auc:0.828404	eval-auc:0.701229
# [422]	train-auc:0.828485	eval-auc:0.701234
# [423]	train-auc:0.828524	eval-auc:0.701237
# [424]	train-auc:0.828666	eval-auc:0.701249
# [425]	train-auc:0.828705	eval-auc:0.701250
# [426]	train-auc:0.828805	eval-auc:0.701234
# [427]	train-auc:0.828962	eval-auc:0.701207
# [428]	train-auc:0.829177	eval-auc:0.701220
# [429]	train-auc:0.829285	eval-auc:0.701243
# [430]	train-auc:0.829360	eval-auc:0.701234
# [431]	train-auc:0.829448	eval-auc:0.701244
# [432]	train-auc:0.829554	eval-auc:0.701341
# [433]	train-auc:0.829751	eval-auc:0.701346
# [434]	train-auc:0.829808	eval-auc:0.701305
# [435]	train-auc:0.829833	eval-auc:0.701297
# [436]	train-auc:0.830027	eval-auc:0.701320
# [437]	train-auc:0.830105	eval-auc:0.701306
# [438]	train-auc:0.830302	eval-auc:0.701348
# [439]	train-auc:0.830488	eval-auc:0.701351
# [440]	train-auc:0.830547	eval-auc:0.701351
# [441]	train-auc:0.830606	eval-auc:0.701337
# [442]	train-auc:0.830730	eval-auc:0.701316
# [443]	train-auc:0.830817	eval-auc:0.701348
# [444]	train-auc:0.830901	eval-auc:0.701340
# [445]	train-auc:0.830993	eval-auc:0.701316
# [446]	train-auc:0.831015	eval-auc:0.701302
# [447]	train-auc:0.831041	eval-auc:0.701328
# [448]	train-auc:0.831221	eval-auc:0.701285
# [449]	train-auc:0.831263	eval-auc:0.701276
# [450]	train-auc:0.831353	eval-auc:0.701305
# [451]	train-auc:0.831507	eval-auc:0.701366
# [452]	train-auc:0.831569	eval-auc:0.701396
# [453]	train-auc:0.831680	eval-auc:0.701408
# [454]	train-auc:0.831817	eval-auc:0.701435
# [455]	train-auc:0.831977	eval-auc:0.701398
# [456]	train-auc:0.832029	eval-auc:0.701379
# [457]	train-auc:0.832168	eval-auc:0.701395
# [458]	train-auc:0.832255	eval-auc:0.701380
# [459]	train-auc:0.832391	eval-auc:0.701392
# [460]	train-auc:0.832548	eval-auc:0.701422
# [461]	train-auc:0.832770	eval-auc:0.701411
# [462]	train-auc:0.833043	eval-auc:0.701432
# [463]	train-auc:0.833175	eval-auc:0.701400
# [464]	train-auc:0.833264	eval-auc:0.701380
# [465]	train-auc:0.833348	eval-auc:0.701386
# [466]	train-auc:0.833490	eval-auc:0.701386
# [467]	train-auc:0.833709	eval-auc:0.701397
# [468]	train-auc:0.833763	eval-auc:0.701364
# [469]	train-auc:0.833876	eval-auc:0.701348
# [470]	train-auc:0.833991	eval-auc:0.701344
# [471]	train-auc:0.834070	eval-auc:0.701321
# [472]	train-auc:0.834215	eval-auc:0.701294
# [473]	train-auc:0.834236	eval-auc:0.701289
# [474]	train-auc:0.834327	eval-auc:0.701280
# [475]	train-auc:0.834392	eval-auc:0.701291
# [476]	train-auc:0.834447	eval-auc:0.701273
# [477]	train-auc:0.834627	eval-auc:0.701250
# [478]	train-auc:0.834789	eval-auc:0.701267
# [479]	train-auc:0.834933	eval-auc:0.701307
# [480]	train-auc:0.835020	eval-auc:0.701303
# [481]	train-auc:0.835261	eval-auc:0.701271
# [482]	train-auc:0.835339	eval-auc:0.701281
# [483]	train-auc:0.835456	eval-auc:0.701241
# [484]	train-auc:0.835531	eval-auc:0.701220
# [485]	train-auc:0.835651	eval-auc:0.701201
# [486]	train-auc:0.835702	eval-auc:0.701198
# [487]	train-auc:0.835867	eval-auc:0.701205
# [488]	train-auc:0.835953	eval-auc:0.701219
# [489]	train-auc:0.836026	eval-auc:0.701225
# [490]	train-auc:0.836047	eval-auc:0.701219
# [491]	train-auc:0.836090	eval-auc:0.701210
# [492]	train-auc:0.836113	eval-auc:0.701187
# [493]	train-auc:0.836288	eval-auc:0.701162
# [494]	train-auc:0.836511	eval-auc:0.701203
# [495]	train-auc:0.836548	eval-auc:0.701199
# [496]	train-auc:0.836676	eval-auc:0.701182
# [497]	train-auc:0.836781	eval-auc:0.701196
# [498]	train-auc:0.836843	eval-auc:0.701190
# [499]	train-auc:0.837028	eval-auc:0.701205
# [500]	train-auc:0.837095	eval-auc:0.701171
# [501]	train-auc:0.837213	eval-auc:0.701129
# [502]	train-auc:0.837408	eval-auc:0.701129
# [503]	train-auc:0.837459	eval-auc:0.701129
# [504]	train-auc:0.837487	eval-auc:0.701137
# [505]	train-auc:0.837563	eval-auc:0.701167
# [506]	train-auc:0.837610	eval-auc:0.701217
# [507]	train-auc:0.837726	eval-auc:0.701220
# [508]	train-auc:0.837859	eval-auc:0.701211
# [509]	train-auc:0.838088	eval-auc:0.701197
# [510]	train-auc:0.838194	eval-auc:0.701178
# [511]	train-auc:0.838336	eval-auc:0.701133
# [512]	train-auc:0.838594	eval-auc:0.701071
# [513]	train-auc:0.838674	eval-auc:0.701046
# [514]	train-auc:0.838836	eval-auc:0.701044
# [515]	train-auc:0.838993	eval-auc:0.701046
# [516]	train-auc:0.839151	eval-auc:0.701062
# [517]	train-auc:0.839268	eval-auc:0.701096
# [518]	train-auc:0.839412	eval-auc:0.701087
# [519]	train-auc:0.839561	eval-auc:0.701075
# [520]	train-auc:0.839612	eval-auc:0.701054
# [521]	train-auc:0.839673	eval-auc:0.701048
# [522]	train-auc:0.839798	eval-auc:0.701042
# [523]	train-auc:0.839891	eval-auc:0.701036
# [524]	train-auc:0.839992	eval-auc:0.701019
# [525]	train-auc:0.840261	eval-auc:0.701024
# [526]	train-auc:0.840391	eval-auc:0.701011
# [527]	train-auc:0.840421	eval-auc:0.701005
# [528]	train-auc:0.840525	eval-auc:0.700973
# [529]	train-auc:0.840564	eval-auc:0.700946
# [530]	train-auc:0.840639	eval-auc:0.700954
# [531]	train-auc:0.840739	eval-auc:0.700964
# [532]	train-auc:0.840997	eval-auc:0.700904
# [533]	train-auc:0.841221	eval-auc:0.700897
# [534]	train-auc:0.841291	eval-auc:0.700897
# [535]	train-auc:0.841408	eval-auc:0.700866
# [536]	train-auc:0.841426	eval-auc:0.700861
# [537]	train-auc:0.841548	eval-auc:0.700871
# [538]	train-auc:0.841643	eval-auc:0.700872
# [539]	train-auc:0.841775	eval-auc:0.700882
# [540]	train-auc:0.841811	eval-auc:0.700872
# [541]	train-auc:0.841915	eval-auc:0.700868
# [542]	train-auc:0.842040	eval-auc:0.700865
# [543]	train-auc:0.842270	eval-auc:0.700879
# [544]	train-auc:0.842306	eval-auc:0.700888
# [545]	train-auc:0.842385	eval-auc:0.700887
# [546]	train-auc:0.842506	eval-auc:0.700894
# [547]	train-auc:0.842649	eval-auc:0.700869
# [548]	train-auc:0.842825	eval-auc:0.700891
# [549]	train-auc:0.843082	eval-auc:0.700882
# [550]	train-auc:0.843125	eval-auc:0.700899
# [551]	train-auc:0.843176	eval-auc:0.700905
# [552]	train-auc:0.843188	eval-auc:0.700903
# [553]	train-auc:0.843304	eval-auc:0.700884
# [554]	train-auc:0.843361	eval-auc:0.700884
# [555]	train-auc:0.843499	eval-auc:0.700883
# [556]	train-auc:0.843740	eval-auc:0.700846
# [557]	train-auc:0.843910	eval-auc:0.700868
# [558]	train-auc:0.844026	eval-auc:0.700855
# [559]	train-auc:0.844106	eval-auc:0.700882
# [560]	train-auc:0.844134	eval-auc:0.700901
# [561]	train-auc:0.844315	eval-auc:0.700888
# [562]	train-auc:0.844513	eval-auc:0.700897
# [563]	train-auc:0.844550	eval-auc:0.700909
# [564]	train-auc:0.844618	eval-auc:0.700889
# [565]	train-auc:0.844646	eval-auc:0.700888
# [566]	train-auc:0.844720	eval-auc:0.700897
# [567]	train-auc:0.844852	eval-auc:0.700883
# [568]	train-auc:0.844973	eval-auc:0.700902
# [569]	train-auc:0.845103	eval-auc:0.700858
# [570]	train-auc:0.845263	eval-auc:0.700820
# [571]	train-auc:0.845421	eval-auc:0.700816
# [572]	train-auc:0.845528	eval-auc:0.700862
# [573]	train-auc:0.845688	eval-auc:0.700889
# [574]	train-auc:0.845846	eval-auc:0.700936
# [575]	train-auc:0.845882	eval-auc:0.700928
# [576]	train-auc:0.845997	eval-auc:0.700874
# [577]	train-auc:0.846030	eval-auc:0.700842
# [578]	train-auc:0.846105	eval-auc:0.700841
# [579]	train-auc:0.846420	eval-auc:0.700805
# [580]	train-auc:0.846444	eval-auc:0.700795
# [581]	train-auc:0.846466	eval-auc:0.700782
# [582]	train-auc:0.846519	eval-auc:0.700781
# [583]	train-auc:0.846694	eval-auc:0.700850
# [584]	train-auc:0.846880	eval-auc:0.700858
# [585]	train-auc:0.846907	eval-auc:0.700846
# [586]	train-auc:0.846937	eval-auc:0.700853
# [587]	train-auc:0.847019	eval-auc:0.700860
# [588]	train-auc:0.847297	eval-auc:0.700831
# [589]	train-auc:0.847352	eval-auc:0.700858
# [590]	train-auc:0.847369	eval-auc:0.700852
# [591]	train-auc:0.847445	eval-auc:0.700845
# [592]	train-auc:0.847595	eval-auc:0.700812
# [593]	train-auc:0.847739	eval-auc:0.700849
# [594]	train-auc:0.847750	eval-auc:0.700846
# [595]	train-auc:0.847777	eval-auc:0.700858
# [596]	train-auc:0.847847	eval-auc:0.700834
# [597]	train-auc:0.847989	eval-auc:0.700857
# [598]	train-auc:0.848158	eval-auc:0.700858
# [599]	train-auc:0.848170	eval-auc:0.700840
# [600]	train-auc:0.848239	eval-auc:0.700835
# [601]	train-auc:0.848439	eval-auc:0.700830
# [602]	train-auc:0.848480	eval-auc:0.700852
# [603]	train-auc:0.848535	eval-auc:0.700859
# [604]	train-auc:0.848659	eval-auc:0.700841
# [605]	train-auc:0.848850	eval-auc:0.700866
# [606]	train-auc:0.848992	eval-auc:0.700884
# [607]	train-auc:0.849097	eval-auc:0.700886
# [608]	train-auc:0.849275	eval-auc:0.700928
# [609]	train-auc:0.849384	eval-auc:0.700898
# [610]	train-auc:0.849409	eval-auc:0.700893
# [611]	train-auc:0.849568	eval-auc:0.700860
# [612]	train-auc:0.849662	eval-auc:0.700886
# [613]	train-auc:0.849750	eval-auc:0.700880
# [614]	train-auc:0.849793	eval-auc:0.700897
# [615]	train-auc:0.849844	eval-auc:0.700881
# [616]	train-auc:0.849987	eval-auc:0.700893
# [617]	train-auc:0.850114	eval-auc:0.700909
# [618]	train-auc:0.850294	eval-auc:0.700872
# [619]	train-auc:0.850432	eval-auc:0.700853
# [620]	train-auc:0.850491	eval-auc:0.700860
# [621]	train-auc:0.850596	eval-auc:0.700881
# [622]	train-auc:0.850760	eval-auc:0.700881
# [623]	train-auc:0.850798	eval-auc:0.700887
# [624]	train-auc:0.850940	eval-auc:0.700916
# [625]	train-auc:0.850956	eval-auc:0.700916
# [626]	train-auc:0.851158	eval-auc:0.700918
# [627]	train-auc:0.851180	eval-auc:0.700922
# [628]	train-auc:0.851241	eval-auc:0.700918
# [629]	train-auc:0.851349	eval-auc:0.700932
# [630]	train-auc:0.851513	eval-auc:0.700957
# [631]	train-auc:0.851557	eval-auc:0.700973
# [632]	train-auc:0.851584	eval-auc:0.700966
# [633]	train-auc:0.851741	eval-auc:0.700942
# [634]	train-auc:0.851774	eval-auc:0.700938
# [635]	train-auc:0.851956	eval-auc:0.700908
# [636]	train-auc:0.851995	eval-auc:0.700893
# [637]	train-auc:0.852053	eval-auc:0.700888
# [638]	train-auc:0.852166	eval-auc:0.700895
# [639]	train-auc:0.852434	eval-auc:0.700899
# [640]	train-auc:0.852560	eval-auc:0.700892
# [641]	train-auc:0.852608	eval-auc:0.700885
# [642]	train-auc:0.852739	eval-auc:0.700884
# [643]	train-auc:0.852852	eval-auc:0.700892
# [644]	train-auc:0.853021	eval-auc:0.700873
# [645]	train-auc:0.853125	eval-auc:0.700865
# [646]	train-auc:0.853284	eval-auc:0.700864
# [647]	train-auc:0.853333	eval-auc:0.700895
# [648]	train-auc:0.853443	eval-auc:0.700887
# [649]	train-auc:0.853609	eval-auc:0.700845
# [650]	train-auc:0.853764	eval-auc:0.700854
# [651]	train-auc:0.853882	eval-auc:0.700857
# [652]	train-auc:0.853974	eval-auc:0.700923
# [653]	train-auc:0.854059	eval-auc:0.700915
# [654]	train-auc:0.854212	eval-auc:0.700896
# [655]	train-auc:0.854233	eval-auc:0.700894
# [656]	train-auc:0.854347	eval-auc:0.700896
# [657]	train-auc:0.854507	eval-auc:0.700883
# [658]	train-auc:0.854624	eval-auc:0.700949
# [659]	train-auc:0.854745	eval-auc:0.700932
# [660]	train-auc:0.854823	eval-auc:0.700904
# [661]	train-auc:0.854848	eval-auc:0.700897
# [662]	train-auc:0.854874	eval-auc:0.700888
# [663]	train-auc:0.854917	eval-auc:0.700879
# loading data end, start to boost trees

# %% [markdown]
# # Combining models

# %%
deval0 = xgb.DMatrix(df0_eval[columns0].values)
y0 = bst0.predict(deval0)

deval1 = xgb.DMatrix(df1_eval[columns1].values)
y1 = bst1.predict(deval1)


df0_eval['proba_c0'] = y0
df0_eval['proba_c1'] = 1 - y0 

df1_eval['proba_c0'] = y1 
df1_eval['proba_c1'] = 1 - y1 

cols = ['proba_c0', 'proba_c1', 'index_origin']

df_eval_res = pd.concat((df0_eval[cols], df1_eval[cols]), axis=0, ignore_index=True)

print(y0)
print(y1)

df_eval_res.head()
# Out:
# [ 0.58521754  0.32299241  0.74920309 ...,  0.5295555   0.55801564
#   0.5213533 ]
# [ 0.56575465  0.46858999  0.39499402 ...,  0.64521116  0.40201771
#   0.56934792]
#    proba_c0  proba_c1  index_origin
# 0  0.585218  0.414782             1
# 1  0.322992  0.677008             2
# 2  0.749203  0.250797             3
# 3  0.416809  0.583192             4
# 4  0.147908  0.852092             7

# %%
df_eval_res = df_eval_res.sort_index(by='index_origin', ascending=True)

df_eval_res.head()
# Out:
# /home/maxime/local/anaconda3/envs/env-python2.7/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   if __name__ == '__main__':
#        proba_c0  proba_c1  index_origin
# 84092  0.565755  0.434245             0
# 0      0.585218  0.414782             1
# 1      0.322992  0.677008             2
# 2      0.749203  0.250797             3
# 3      0.416809  0.583192             4

# %%
np.savetxt('y_pred_xgboost_optimized.txt', df_eval_res['proba_c1'].values, fmt='%s')
